# %%
tf.VERSION
# Out:
# '1.0.0'

# %%
import tensorflow as tf
import numpy as np
import re
import time

# %%
lines=open("movie_lines.txt",encoding="utf-8",errors="ignore").read().split("\n")

# %%
conversations=open("movie_conversations.txt",encoding="utf-8",errors="ignore").read().split("\n")

# %%
id2line={}

# %%
for line in lines:
    _line=line.split(" +++$+++ ")
    if len(_line)==5:
        id2line[_line[0]]=_line[4]

# %%
id2line
# Out:
# {'L560299': 'Well, how are you enjoying your first day on the job?',
#  'L550761': 'Exactly anything.  Whatever you want.  Whoever you want to be.  Fabri, get us another round, would you.',
#  'L388629': 'Just waiting for you, tubs.',
#  'L653327': "I'll be damned if I'm leavin'. That band is too good?",
#  'L342257': '"- every day."',
#  'L304754': 'What do you want to talk about?',
#  'L622351': 'Medicinal marijuana initiative.  Or am I being cynical?',
#  'L369694': "Are you tryin' to do some of that Polack humor?  Well if that's so, you can just get the hell out of this restaurant!",
#  'L103876': "It's too bad about what happened on the road.",
#  'L598249': 'No good?  This is a disaster!',
#  'L426802': "You're sure it's okay?",
#  'L193722': 'How the hell am I supposed to know? This is your damn city.',
#  'L137464': 'Next time, date only basketball players.',
#  'L534532': 'Or the one.',
#  'L236882': 'Where?',
#  'L184696': "Don't talk.",
#  'L568874': 'How?',
#  'L490588': 'That means Mister Futterman is dead, by golly.',
#  'L610054': "I don't want to die.",
#  'L613492': 'Yes, I saw it--but--',
#  'L279231': 'So so.  Up and down.',
#  'L488766': 'Jennifer needs me.',
#  'L282695': "What's the point?",
#  'L196064': "That's enough!",
#  'L199281': "And two more times tomorrow night, and two more times the next night, and the next night and the next night and the next night.  Frank, I can't sing that fucking song anymore!",
#  'L330449': "What in Christ's name is going on?!",
#  'L503004': 'You give your word on that do you, Mr. Torrance?',
#  'L412842': 'You get another chance in ten minutes.',
#  'L355438': 'You rigged the illusion to fail, right?',
#  'L428893': "Whadaya doin', there's no one there!",
#  'L462757': 'We got a cookaboo inside.  He wounded some kid earlier.',
#  'L191622': "I'd just as soon kiss a wookiee.",
#  'L362268': 'Right.',
#  'L565151': "Don't you ever get messages, Eyelashes?  I called you twice.",
#  'L527881': "Don't you?",
#  'L441856': "You've got sand, for a maid.",
#  'L339591': "I've seen it before.",
#  'L572599': "You're joking.",
#  'L564774': "What's that, Dolores?",
#  'L53632': "I don't know. This wall isn't like the rest though, it's not all that old either.",
#  'L378696': 'What do you got on Korda?',
#  'L420572': "Dick, these boys want you to run.  They're serious.  They can deliver the South and they can put Texas in your column.  That would've done it in '60.",
#  'L85344': 'Visiting friends of hers in Palm Springs.  Just picked up and left, never bothered to tell us.',
#  'L6357': "He's an imbecile.  I tried to warn my daughter, but what can you do?",
#  'L184000': "You're the prettiest girl I ever saw.",
#  'L209091': "Where ya comin' from, young man?",
#  'L612174': "You're not cleared for this precinct.  Let's cross over first.",
#  'L373443': 'They are dead.  In either case --',
#  'L175799': "Oh, flowers!  I didn't know you were so traditional.",
#  'L352339': "I'11 meet you in the car.",
#  'L634593': 'The car accident you were in... Was there anyone else involved?',
#  'L284302': 'Ssh!',
#  'L599391': "I've got another one.  Warmer.  What will you do when it's all over?",
#  'L543063': 'Are you my friend?',
#  'L368343': "Yeah I'm sure!  I did it with my own hands!",
#  'L325840': "Because it's a ritual you gotta go through with. I'm down to 10.",
#  'L334294': 'How long did you fuck her?',
#  'L124414': "I know he's there!  He doesn't even have the balls to pick up the phone!",
#  'L441441': "I'd heard of <u>something</u>. The gay plague, gay cancer, but... we didn't know how you could get it, or that it could kill you.",
#  'L315669': 'Paul Gruneger!',
#  'L5057': "I suppose you'd never be like Luther and let a woman get to you...",
#  'L422975': "'Cartwright, Wainwright, whatever your name is, I promised little Jimmy I'd be home for his birthday -- could you get a message through that I may be a little late.'",
#  'L427269': "You're no better than me, Paula! You're just the same!",
#  'L89510': "That's right. The answers were there all along, of course, scribbled down in the forgotten languages of my kind. Waiting for someone with the patience to decipher them. My elders were foolish enough to dismiss them as wives tales. But I knew better.  Imagine my surprise when Blade turned out to be the key which would set that force free.",
#  'L568436': "Now, that young conductor what's his name?  That miracle kid, you know who I mean. Von Karajan! But you called him something else. C'mon. What did you call von Karajan?",
#  'L456331': 'Could we go somewhere?',
#  'L86743': 'I just wanted some make-up.',
#  'L266001': 'Oh, my <u>program</u>...',
#  'L463593': "Hotwiring cars, Rudy, does not qualify as a small business. Chop shop consultant; doesn't work on a resume.",
#  'L244431': '"I want to tell you something, Harriet..."',
#  'L303761': 'Let me call you back...',
#  'L637883': "Okay.  Now, so he's in jail.  He, finally, he gets to see the light, he calls up Harrington, he says he thinks he made a mistake.  As if by magic, charges against him are dropped, he's released from jail.   P.S.  He's fired from the firm, his wife divorces him, he turns to drink  and mopes around three and a half years.   You like that story?",
#  'L644357': 'Well, you know, "The Whole Thing\'s Theatre..."',
#  'L603678': 'Sir, that curriculum is forty years out of date.  The students today are looking toward the new century -- they want to be challenged and inspired, not spoon-fed dusty old equations that have been proved a thousand times.  They want to explore.',
#  'L234496': "Utah, the Bee-Hive state. I'm from Orem, right near Salt Lake ... Say, you wouldn't happen to be a Mormon, would you?",
#  'L103612': 'Right here.',
#  'L195409': "I'm a friend of Bonanza Jellybean's.",
#  'L445143': 'I know that.',
#  'L149570': "No it doesn't. I see right through you.",
#  'L597618': 'What do you suggest?',
#  'L434474': 'Have they got Midge up there?',
#  'L6577': 'Three, four years.',
#  'L315877': 'What the hell is that supposed to mean?',
#  'L569082': 'Can we go up? Do you mind?',
#  'L259267': "I think we've got something.",
#  'L135309': 'Here you go.',
#  'L393180': 'Hey--I wanna *scoop*!',
#  'L422595': "No, it's a stupid privacy thing.  I always choose a cartoon character -- last time out, I was Mrs. Bambi.",
#  'L585221': 'No.',
#  'L356623': 'Charlie, this is Bob. Bob  Charlie Brown.',
#  'L125260': "Thing is, Dil, you're not a girl.",
#  'L303926': 'Hardly new news.',
#  'L128599': 'God, man!',
#  'L194984': "I'm sorry.",
#  'L550009': "You know every story, every wound, every memory, their whole life's <u>happiness</u> has been wrapped up in <u>you</u>, every moment...",
#  'L255955': 'Looks very solid, Lilly. Sit down. Take a minute, tell me about it.',
#  'L593920': "I guess I could be chalant about it, but then again I'm not even sure if that's a word. Listen Chief, we could stand around arguing all day, but I gotta case to crack.",
#  'L328835': 'When I met you, I thought that one day millions of years ago, all the dinosaurs became extinct. Wiped out. But you told me otherwise. When conditions changed, dinosaurs changed. They became other things. They evolved.',
#  'L447826': 'Oh, Biff. You can "pin" me any time you want to.',
#  'L552332': "Perfect.  Thank you, Major.  And now let's drink a toast.",
#  'L574924': "Butcher's hook.  Look.  I don't much reckon those minders of his.",
#  'L205533': "I'm not gonna sit here and debate. I will say this though: what Shep told us didn't make a whole lot of sense.",
#  'L84264': "Can I ask you a question? Why did you come here today? If you found this deed, why didn't you just ask Eddie?",
#  'L446840': "What's a buzzer?",
#  'L273854': 'Finish what?',
#  'L130226': 'His girlfriend?',
#  'L478098': 'No.',
#  'L331841': 'I will not get drawn into another financial conversation with you, Dennis.  I really will not.',
#  'L107159': "Don't be sorry.  Help me.",
#  'L473083': 'Do what?',
#  'L76721': 'Huh huh huh. He said "anus."',
#  'L279226': "Hi, Rob.  It's your mother.",
#  'L199241': 'You always threw up.',
#  'L187925': 'Your Majesty! We come from a world where there IS no music. Where men live and die by the axe and by the sword...',
#  'L612621': 'Remember this...?',
#  'L603045': 'They were kidding you.',
#  'L391100': 'When your husband get hit by the bus?',
#  'L19307': 'Elaine, not yet. I promise you I really can change.',
#  'L553727': 'Mm-hm.',
#  'L121063': "...twenty years in order to find nothin' on me -",
#  'L172889': "Oh no, I know that class isn't for me. But I'm happy for you guys.",
#  'L44904': 'His Snapples were in alphabetical order.',
#  'L462013': "You can't protect me.",
#  'L399966': "No, not really. They're about the same. My marriage was one long headache.",
#  'L484447': 'I know.',
#  'L434283': 'It would be worth the risk.',
#  'L12823': "I don't know. For the food business. I guess. I just thought, you know, we'd sneak a Big Mac on Mommy, like we used to.",
#  'L539787': 'I have to go back to the silo. Will you be all right?',
#  'L64730': 'Do you want to see the loveliest woman in Europe?',
#  'L625693': "We'll get them, sir... These things take time.",
#  'L357310': 'That, my dear Conway, is the story of a remarkable man.',
#  'L399663': "Oh, so that's him? The Panda Man.",
#  'L508700': "Jesus, look at you   You're glowing.",
#  'L66240': "That's it. You're that policeman with friends in low places. Tell me, how's Guissepe Torres doing these days? Those racketeering indictments must have really been a downer --",
#  'L215345': 'Damn, they always stick me with the clunker.',
#  'L648363': 'Sit down here.',
#  'L282598': "You won't.",
#  'L313284': "I called in sick this morning. As far as the airline knows, I'm still available.",
#  'L471300': 'Gee, you shamuses are a tough audience, but what happened to you that was so dark, lurid, embittering?',
#  'L551589': "I'm in to the directory but they've codified the stockpile--numerically.",
#  'L251538': "Benjamin -- you're -- I don't know what to say -- you're --",
#  'L416814': 'What is this place?',
#  'L46738': 'Let me take that.',
#  'L428196': "Yes, ma'am.",
#  'L598232': 'W-w-what are you doing?!',
#  'L247925': "I'm just here about my brother.",
#  'L653234': "I'll tell ya though, it's comin' up to the time when Marietta and me might just set up house together and settle down... I think that time's comin' up right soon. But like you said, everythin's relative.",
#  'L120479': 'But I knew how to keep the bosses happy. Whenever they gave me little jobs to do, you know, to send a message, I would carry things out...',
#  'L419790': 'They always belonged to the Russian people. They were paid for with their sweat, their blood, their lives and you will give them back!',
#  'L500247': 'Here.',
#  'L59480': "Ah, Cole.  I don't remember ordering an asshole from room service.",
#  'L362818': 'Mmm.',
#  'L99707': "Her.  It's an obvious move.  I'm building a case against her, remember?",
#  'L127104': "What I don't understand is why they asked Marliston if Rod was a virgin. They could have asked you Cindy.",
#  'L248609': 'Call 911 -',
#  'L454956': "I'll go pay for my car.",
#  'L91637': "What's she look like?",
#  'L260355': "You won't come on too strong.",
#  'L307087': 'Wait! He works for YOU?',
#  'L378508': 'Let me take you out tomorrow night... Pleeease.',
#  'L298400': "And the good news is you won't charge me.",
#  'L92719': "That's always a good idea! Would you like some money? I have a great deal of it.",
#  'L14119': "Why didn't you take her to a doctor?",
#  'L114283': 'Everyone wants to meet the bus boy.',
#  'L622098': "I can't go home because there's no home left.",
#  'L390773': 'Are you ready?',
#  'L169059': 'Yeah... you know...  Fucking.',
#  'L533470': 'Yeah. Security.',
#  'L497197': 'Student?',
#  'L448349': 'I had nothing to do with that.',
#  'L383134': "You ain't got a chance in hell. You need threads and glitter, baby. A front, hey?",
#  'L129724': 'Look, you tell me to take pictures, I take pictures.',
#  'L389467': 'The goddamned bastards.',
#  'L501140': "They're not?",
#  'L176975': "She left. She moved. She got Fed-Ex to give her a transfer and she left. She couldn't stand it anymore. We had people, news people, regular people, just sleeping in our hallway, going through our mail, our garbage. I mean it was she couldn't take it anymore. Now I've got to move. I can't afford this place by myself.",
#  'L522568': "I'll have to pack a lot of clothes.",
#  'L92303': 'My eye, is there something in my eye?',
#  'L363049': 'DAD.',
#  'L383133': 'You talk like a man with a tin twat.',
#  'L246052': 'Getting to be a warm day.  A scorcher, as you Yanks call it.',
#  'L585877': 'Ilio Manzetti...former ambassador to France. Managing partner at Damon, Schwarzchild.',
#  'L237028': "I promise I'll take good care of it.",
#  'L513570': 'Welcome home.',
#  'L406813': 'Hal? Well, Hal and I have been friends for a long time.',
#  'L27683': 'Hi.  Hello, darling-',
#  'L295371': "Sarah.  Eddie, look. I've got troubles, and I think maybe you've got troubles. Maybe it'd be better if we just leave each other alone.",
#  'L636847': "We've got her sister. Testifies she had a meal one hour before she was admitted to the hospital. This is the point.",
#  'L271119': "I'll think about it.",
#  'L284437': "That one -- how you gonna take him? They'll see him.",
#  'L506820': 'Yeah, Winesburg, Ohio, was never like that... but I got something that just might cheer you up.',
#  'L250427': 'Save it for your mother, funny guy. We heard it before.',
#  'L330537': 'Oh, God.',
#  'L3392': "Don't say anything.",
#  'L239208': "Yeah, I guess so.  It was the strangest thing.  I knew what I was doing but I couldn't stop.  This really terrible feeling came over me and -- I don't know -- I just felt like driving into that tree and ending it all.  Whew!  Sorry, boys.",
#  'L462632': 'Of course.  Drown them like puppies.',
#  'L207336': 'Hi, Stacy. How are you?',
#  'L451262': 'Look I just wanted to say goodbye.',
#  'L544931': "Maneuvering thrusters, Mr. Sulu; ahead one third.  Full sensor scan, Mr. Spock; they can't expect us <U>not</U> to look them over now!",
#  'L437904': 'Sorry.',
#  'L257910': "She was in pretty bad shape. They've done a C.A.T. Scan -- she has some hemorrhaging...",
#  'L133073': "But Alfredo, what you're saying is horrifying!",
#  'L251224': 'No sir. I am not proud that I spend my time with a broken-down alcoholic!',
#  'L335991': 'Yup.',
#  'L142260': 'You do recognize it then?',
#  'L236857': "We'll just go in for one minute -- it'll be a riot!",
#  'L635200': "I wouldn't point no pistol at nobody, sir.",
#  'L575245': 'Hell, no.  I started writing.',
#  'L246401': 'What are you then?  What will you be ten years from now?  Still cutting lawns?  Still banging horny divorcees in your trailer?',
#  'L335774': 'Look -- dad -- I may stand better with the cops than you.',
#  'L237110': 'Yeah, I guess... call me...',
#  'L118740': "Yes, ma'am.",
#  'L401520': 'We have new "guests" for the park. I have a file on them. May I see Bruce ?',
#  'L653659': "Someday honey, I will... But I have to be goin' now... Conta i no joras...",
#  'L566421': 'Can I check my messages? I have a calling card.',
#  'L368657': 'He is good. Bur not as good as Price.',
#  'L107164': 'No.',
#  'L518210': "You didn't bring any chocolate, did you?",
#  'L486565': 'Popcorn.',
#  'L371741': "Well, Dad, we haven't found any holes in the large bowel. They've all been in the small bowel, but the smell is different. I caught a whiff of large bowel, but it ain't staring us in the face, right?",
#  'L607742': "Captain, belay that order!  Bob, where's that coming from!",
#  'L555539': 'He wants me to come on to Arizona. He says it only oosts two dollars to get married there.  It would kind of save us a honeymoon.',
#  'L417345': 'Only one thing can save the children. The unquiet spirit must be laid to rest.  It is an abomination to God and Man.',
#  'L501109': "Nothing, I'll call you, okay?",
#  'L237369': 'Huh?',
#  'L633629': "You son of a bitch! I'll have my lawyers shut you down.",
#  'L489668': "It's be best if you got to the point, cause I'm about ready to punch you in the face.",
#  'L649802': 'Hell - Julien believed it... Carlotta too... and god knows, more than a few of us called her a witch!',
#  'L349467': 'We can work.',
#  'L630185': "If we can't change anything...because it's already happened, then we ought to at least smell the flowers.",
#  'L161316': "We have an antidote that'll retard the aging process.",
#  'L63522': 'Say what, Manray?',
#  'L28011': "Well, I was sure you'd want to, of course, being his birthday, and you've been so busy these past few days, and last night I meant to tell you before you went out with the Richards - and I guess I was asleep when you got home...",
#  'L127917': 'And let me guess.  You failed.',
#  'L424043': "So how's it going with your new roomie? What's her name?",
#  'L245653': "Like hell!  And who the hell are you to give me orders.  Watch your manners or you'll be on your Sicilian ass in the street there.",
#  'L291078': 'Yeah. But, hey, anybody who\'s not "comfortable" with the rules, you\'re free to walk, anytime. Seven digits poorer, goes without saying.',
#  'L248409': 'Everyone know Ray Calitri? Pillar of the community ...',
#  'L523649': "Come, I'll take you home.",
#  'L117350': "Nuke won't go to bed with you, eh?",
#  'L527483': 'Resetting the sub.',
#  'L313259': 'I felt a lot safer having it. My milk went bad when I was in jail.',
#  'L346304': 'Aye.  We be on a quest to set the world aright --',
#  'L630148': "No superiors!  No scientists.  No people from the future.  It's just a Carpet Cleaning Company.  They have voice mail -- you leave a message telling them when you want your carpet cleaned.",
#  'L85816': 'It is. I did it cooking.',
#  'L308916': 'It makes me fear her.',
#  'L515815': "Man, that's great.",
#  'L507246': "She's already here.  She arrived before you and she'll leave long after you've gone.  Remember, under no circumstances are you or any other person to enter the set without my express permission.",
#  'L629960': 'The gun! ... I lost it',
#  'L568201': 'Did you call someone you knew?',
#  'L552792': 'No kidding.',
#  'L617567': "Run.  Take that girl and start Running.  Run and don't look back. All your life you been running And looking back and just barely Existing and calling it getting By.  This time run and don't look Back and call it living.  Live Every second, live it right up to The hilt.  Live, Wyatt...  Live for me.",
#  'L184988': "Are you under the impression that now I'm in some way obligated to you?",
#  'L119322': 'Come up here a minute.',
#  'L213200': "I'm not disclosed to bespeak any such information to you, nor would I, even if I had said information you want, at this juncture be able.",
#  'L360995': 'What the fuck was that about?',
#  'L487742': 'And an explanation is, of course, out of the question.',
#  'L83106': "Very talented son of a bitch. Too bad we can't kill him.",
#  'L62721': "I think that would probably make you the happiest.  When I'm hoofing, I mean really doing my thing, hitting it, nothing compares to that feeling in the world.",
#  'L60772': "Who's doing this?",
#  'L66722': 'Because of what I saw.  Who really killed West.',
#  'L354510': 'You told me one time it was true love.',
#  'L637930': "No, actually, she was referred to me.  She was Dr. Hagman's patient...",
#  'L380353': 'Verdado where?',
#  'L405189': 'Be a Mohican. ',
#  'L480459': "Okay, but if I get yelled at, I'm never gonna listen to this show again.",
#  'L600230': 'Three different guys?',
#  'L520955': 'Hey, Sheboygan - you two - what was your last job - playing square dances?',
#  'L572794': "It's just money.  You should be glad you're alive.",
#  'L496379': "Wait a minute. This has got a lot of angles. You've got to take it easy. Do you know a Mrs. Redi?",
#  'L440571': "Catch me later, I'll be here. And tell Amy, I love her painting, it's on my wall.",
#  'L426627': 'What did you call me, boy?',
#  'L265676': 'I met a man, and His Troubles Were Greater Than Mine...',
#  'L514276': "If you want to steal it, that's your business. At least I won't have you around here making noise.  It might be worth it.",
#  'L288869': 'My sister is dead, Paul. They would not leave the children.',
#  'L81335': 'So...? Where the hell is it?',
#  'L447726': "She won't go out with me?",
#  'L477828': "Juntao's standing orders were to kill everyone. There were never witnesses.",
#  'L449706': "Good guess.  There's a gun on you right now.",
#  'L278596': 'Paul Newman in "The Hustler."',
#  'L151845': "Mark wouldn't hurt a fly.",
#  'L618089': "That's reassuring.",
#  'L328115': "Dave, you know that's where this road leads.",
#  'L154972': 'First Lady...',
#  'L392831': "Really, my dear--I don't feel like a thing.",
#  'L550377': "Well, no. I'm doing one on high school students, in fact.",
#  'L502210': "Well, I'm looking for a change.",
#  'L375645': "Oh yeah?  What was 'fascinating' about it?",
#  'L221674': "I'll have someone show you to your room.",
#  'L183439': 'Yeah?',
#  'L457938': 'Hey, Mattie, dig into the morgue and send up all the art you have on Joan Gale.',
#  'L433728': 'None of your business.',
#  'L83749': 'Ruth McHibbon offered to pick you up at the airport.',
#  'L601199': 'Yes sir.',
#  'L533520': "I thought that's what you said. You're from Cleveland. And you were with the Thirty-sixth Bomb Group?",
#  'L169878': 'See ya around.',
#  'L407809': 'Unfortunately, yes.',
#  'L630070': 'You really want to know?',
#  'L372849': 'Most guys do.',
#  'L250198': "See, now this doesn't feel right.  When I made the decision to come over here it felt right. I had all these rationalizations... I just don't understand why Will never tells me anything, he won't let me get close to him, he tells me these weird lies--",
#  'L387219': 'I understand.',
#  'L237192': "Oh yeah... maybe... Seymour's going on his big date tonight and I kind of want to be around when he calls, so I can hear how bad it went.",
#  'L260228': 'Night Doc.',
#  'L354760': 'Aqui! Venga por aqui! [Over here! Come this way!]',
#  'L166983': 'Of course not ...',
#  'L553742': "I don't know.",
#  'L511060': "Let's say today, we make it your business.",
#  'L390059': "I'm comin' for my twenty thousand.",
#  'L569179': "Don't you put the past in a room, in the cellar, and lock the door and just never go in there? Because that's what I do.",
#  'L387175': "You're alive?",
#  'L629821': 'Uh, no.  Yes.  I mean, just some scrapes...',
#  'L476041': 'Oh yeah.  Between here and Vegas we get a lot of customers.  All types.  Even had an officer, just like you.',
#  'L123276': 'Uh-huh..',
#  'L274987': "You're still afraid.",
#  'L28873': 'Max is paying for it. He and Lloyd had a terrific row but Lloyd insisted... well. Can I fix you a drink?',
#  'L661757': 'What?',
#  'L380256': "Here's what this is...ask how much they want to turn back to us our load...",
#  'L103143': "That's not what I meant, Dignan.",
#  'L652185': "You ready for your big coming out party? Everybody's dying to meet you.",
#  'L257307': 'I was catching up with Bob Destephano.',
#  'L482117': "I insist. It's delicious. Just a taste.",
#  'L263191': 'Gosh, you really went through a crisis, you know that?  H-how did you get over it?  I mean, when I ran into you, you seemed, you seemed just perfectly fine.  Well, you seem fine now.',
#  'L203233': "Reed. Even you can't compute every little thing.",
#  'L76469': 'Big day today, huh? 78',
#  'L489264': 'No.',
#  'L491251': "Ooh, honey, I'm ready! Now! Now!",
#  'L461075': 'Yeah. I sure feel sorry for you, Gunnison. Must be rough on you thinking of me wearing this cast another whole week.',
#  'L119488': 'Ask Monsieur Rick.',
#  'L205735': "No, see, I don't need a finder's fee, I need - finder's fee's, what, ten percent, heck that's not gonna do it for me. I need the principal.",
#  'L248153': 'On account of me.',
#  'L417472': "Yeah, but here you are.  How'd I get so lucky?  I thought you were trying to forget I was alive.",
#  'L477708': 'Yeah, sure, you got lots a enemies in L.A. after what?  Six hours?',
#  'L369411': 'Will?',
#  'L510779': 'Maybe you should tell that to the old lady you tried to hit with the shovel.',
#  'L624053': '  ',
#  'L386688': 'You know I need to use you.',
#  'L170092': 'Later.',
#  'L149709': 'I was just being honest. You happen to have a nice ass. Sorry.',
#  'L414408': 'Decide to take a day off after all?',
#  'L332005': 'The kids okay?',
#  'L354096': 'These ones coming up are getting stupider every year.',
#  'L124554': 'Come and get me, soldier --',
#  'L118287': 'Lung cancer?',
#  'L23488': "What's up?",
#  'L365': 'You have my word.  As a gentleman',
#  'L232516': 'Well, I remember a philosopher who said something that I used to think was just another of those stupid class denouncements... but which I now see means us all.',
#  'L510874': "Hold it, hold it. Aren't you forgetting something, Rod?",
#  'L270333': "But I don't play anything.",
#  'L124955': 'Jimmy.',
#  'L480986': "He's over at the boat show. He'll be by later.  It's so beautiful here.",
#  'L535890': "He's just going to hang around the bushes while we eat?",
#  'L597031': 'Lets go.',
#  'L253168': 'The war.',
#  'L409240': "You know, Doris - you'd make some guy a swell wife.",
#  'L622178': 'Ah, you should see the swan! His masterpiece. Now, walk along the beach and stoop to pick up the shell.',
#  'L366845': '[Four-seven-four-seven.]',
#  'L145742': 'Can I put these here for tonight?',
#  'L27595': 'Couple more seconds!',
#  'L374017': 'Uh...can we give you a check?',
#  'L6548': 'Can I interest you in a battery operated-vagina?',
#  'L542790': 'Closed?',
#  'L592905': 'Who is he?',
#  'L39277': 'Right.',
#  'L137272': "Bring down the money or your friend's dead!",
#  'L377243': 'No. Just leave the stuff lying around as if it were yours. Like you just took it off or something.',
#  'L601211': "And a packing company, a chain of Savings and Loans and half the politicians in Chicago and New York. There ain't a fix in the world gonna cool him out if he blows on ya.",
#  'L391383': "It's the best thing there is.",
#  'L591721': 'You wrote this?',
#  'L595147': 'What do you mean?',
#  'L580334': "What is it? Kiddie porn again? Sexual battery of a patient? I've had my license taken away in three states.",
#  'L243953': 'Polacks and deadbeats.',
#  'L73632': 'What is it about the wrong kind of man? In grade school it was guys with earrings. College, motorcycles and leather jackets.',
#  'L352767': 'What are you talking about?! I saw you let a Runner go?  I saw you, Logan?? Tell me!!',
#  'L542743': "George, we've just confirmed the existence of the live extraterrestrial.",
#  'L197169': "Hasn't Merlin mended your wound?",
#  'L195901': "We're losing pressure at 280 liters a second and our oxygen tanks are cracked. In three minutes, our atmosphere will be gone. We are fucking dead.",
#  'L416799': 'I just got here myself.  Went to the Public Library.  Cut four classes!',
#  'L326916': "Do I know everything there is to know here?  You fellas aren't talking with Bob Sugar, are you?",
#  'L393803': "It's in your lap, Joe. Keep an eye on him. If he gets to his feet and says anything--",
#  'L460262': "That would scare her to death. She's terrified of hospitals. To her, a hospital is where you go to die.",
#  'L154123': "SHHH!  Don't do that!",
#  'L607624': "I'm gonna protect those pilots.",
#  'L290378': 'Why?',
#  'L137554': 'Take the rope.',
#  'L433692': 'No?',
#  'L256937': "It's nice to see you again.",
#  'L487919': "We're aware of that.",
#  'L426559': 'What for?',
#  'L475685': 'What?',
#  'L76254': "Okay.  It's not a problem... Let's just sit ... I'11 talk to the gallery ...",
#  'L282233': 'Not tonight.  Tonight I have a drink with an old friend.',
#  'L92880': 'Right.',
#  'L106557': 'Basically.',
#  'L487412': "Don't shoot. It's me.",
#  'L361245': 'But, Max --',
#  'L194968': 'Do you remember anything else? What I was wearing? Was I standing close to him? Was I leaning against his car like I owned it? How did he look at me when I giggled? Tell me everything.',
#  'L315414': 'Who?',
#  'L256813': "He didn't.",
#  'L103938': 'John Mapplethorpe.  How are you. Hi.',
#  'L281455': "I'm gonna nail you, Nash.  That's a promise.",
#  'L319595': "I'm sorry, Martin. She's in a sick, terrible state.",
#  'L655073': "Drop dead... You know where my mom is trying to get the money to pay you off? She's trying to break my trust.  How do you like that?  I can't touch it until she's dead and she won't give me a dime and now she's trying to break it to pay you...",
#  'L400507': "Skip and I wouldn't have got together if it weren't for you. That's a big deal.",
#  'L283975': 'But, gee, Hildy -- he gave us that insurance business -- and you promised --',
#  'L133098': 'Toto, are you pulling my leg or something? How is it possible to see this television without film?',
#  'L235905': 'Did you see him?',
#  'L41241': 'I was just wondering since we already have the dress. . .',
#  'L354923': "Yeah.  It's French.",
#  'L133798': "What's wrong, Brad?",
#  'L305803': 'Louis, put me in my coffin...',
#  'L332297': 'Oh my God.  Aw, God.',
#  'L16614': 'Conference rooms, though some have other functions.  The one up front doubles as an emergency medical center.',
#  'L648052': 'Not like this.  We were never like this.  I want to go over there.  After dinner, we can--',
#  'L220408': 'Twelve pack?',
#  'L320321': 'Look, humor the old man -- just be careful.',
#  'L459912': "Ohhh-hh... what's happening now?",
#  'L224948': "What'd you see?",
#  'L279827': 'It was Jan, and it was a long time after--',
#  'L662132': "It's a bad idea.",
#  'L127281': 'You know her?',
#  'L14067': 'He talked to you Himself?',
#  'L14010': 'No... not in the eyes of the police.',
#  'L60396': 'You like everybody, Ronald.',
#  'L247227': 'Great. See ya then.',
#  'L14291': "That was the beginning, the night of the conception. That's why she burnt the sheets.",
#  'L126933': "Never mind -- I'll go by myself.",
#  'L76856': 'Uh, B...A...U... No, uh, V...',
#  'L288773': 'Gregoire, what are you doing here?',
#  'L423838': 'Joyce was screwing Del.',
#  'L320404': "You stay right here.  You're going in with me.",
#  'L14090': "It's a sin to be fat.",
#  'L473100': 'I would have tried not to.  But yes, if it would have kept him from shooting you, I would have.',
#  'L439734': 'You and this old Indian rag-man--',
#  'L522316': 'Very nice.',
#  'L12726': 'Wade, are you alright?',
#  'L660471': 'And think to yourself -- "There\'s no place like home; there\'s no place like home; there\'s no place like home."',
#  'L119194': 'Yes. I found that a very expensive hobby, too. But then I never was much of a businessman.',
#  'L197536': "I don't know, I just thought.",
#  'L640414': "He's weird.",
#  'L431293': "I'll go down the line, Kayo, believe me.",
#  'L566165': 'What are you talking about? Vegas?',
#  'L151996': "She says she's on the rag every time I get called in to investigate a murder.",
#  'L115234': 'None of your business.  God.',
#  'L97543': 'Who knows you have these?',
#  'L4198': 'Two more.',
#  'L454763': 'You look nervous.',
#  'L477819': "You don't. He finds you. Through his people.",
#  'L524562': 'Hey, come here, guy.',
#  'L300553': "What're you talking about -- I'm not a dope fiend! I saw it! I'll show you!",
#  'L103449': "Look, man. She didn't know anything about shirts.",
#  'L66441': "Pills, shots, you name it, Basic's a lot easier when you don't feel pain --",
#  'L85851': 'So what are you going to do?',
#  'L518568': "Don't do this.  I am literally begging you not to do this.  Chris.",
#  'L248600': 'What are we gonna do -- ?',
#  'L513559': "Howdy, Mr. Grant. You goin' to the Deer Cheer this weekend?",
#  'L302726': "What's wrong with how I carry myself.",
#  'L404716': 'What happened?',
#  'L655300': 'Merritt, Forensics.',
#  'L123871': 'Our house always needs touching up.',
#  'L306966': "Like I know his intention? Or yours for that matter?  I should join Sam. I'm too old for this bullshit.",
#  'L608141': "It shouldn't have. But it did.",
#  'L437931': "It's not your fault, Rafe.  The letter I wrote you, they --",
#  'L2636': "Don't speak Russian!",
#  'L573187': "Don't worry, I probably won't be in here much.  Light sleeper.",
#  'L254348': "The rest of my fambly set out for the west--there wasn't nothin' to eat--but I couldn't leave. Somepin' wouldn't let me. So now I just wander around. Sleep wherever I am. I used to tell myself I was lookin' out for things, so when they come back ever'thing would be all right. But I knowed that wan't true. There ain't nothin' to look out for. And ain't nobody comin' back. They're gone-- and me, I'm just an 'ol graveyard ghost--that's all in the world I am.",
#  'L288480': 'Good evening, Odette, who is sick this time?',
#  'L306385': 'I assume this is on Rex?',
#  'L548540': 'Who got their heads cut?',
#  'L302514': 'Then what are you stopping for?',
#  'L559056': 'What?',
#  'L452398': "You think you're not in prison now? Living in a grey little room. Going to a grey little job.  Leading a grey little life.",
#  'L587662': 'Pete...',
#  'L376188': "No, anything is possible.  It's up to Joe.",
#  'L405211': 'Agents?',
#  'L652709': 'They kept this scrapbook of your life. It meant the world to them.',
#  'L446366': "She's just a girl I met on the train. You don't mind do you?",
#  'L290612': 'Lock the fucking doors.',
#  'L438811': 'Hello, Charlie.',
#  'L475121': 'If you want to go on, I can make it all right.',
#  'L412321': "Dude, dogs hate me.  I don't know why. Me and K-9's just don't get along.",
#  'L130851': "I haven't read that.",
#  'L540534': "It's an old psychological strategy, Number One. To put him in a position of dominance and make us uneasy.",
#  'L288326': "You wanted to let Sonny handle it.  I would've moved in when we first found out.",
#  'L435221': "That's right brother... listen and learn.",
#  'L234573': 'When they find it, they find it.',
#  'L600017': "Ted, I'm so sorry. Are you going to be okay?",
#  'L659473': 'Stop her!',
#  'L389897': "What you mean? Tommy ain't done nothin'.",
#  'L661956': "I don't want to see any goddamn pictures.",
#  'L396501': 'By whose authority?',
#  'L337828': 'You ever see her talk to the walls?',
#  'L296888': "And you're still trying to get me into bed.",
#  'L662501': "You're a cop. Figure it out.",
#  'L370375': 'What makes you say that?',
#  'L288897': "I don't know. Colonel Oliver says the UN has three hundred soldiers for the whole country. Black soldiers, Pakistanis.",
#  'L356602': 'Are you sure you have to go?',
#  'L227871': "That's what you think?",
#  'L321849': 'I just did.  Can you make them do tricks?',
#  'L85096': 'Huh?  No, she, she hit me right here.',
#  'L556285': "It's lovely. . .",
#  'L354182': 'This is an official visit, then--',
#  'L349319': 'Sam?',
#  'L470205': 'Wait here, gotta smooth this guy out.',
#  'L356548': 'Ok.',
#  'L544874': 'Instruments fluctuating, Captain. Patterns unrecognizable.',
#  'L550425': "Thanks. I'll tell Mike.  Well, it's still just a beginning. I know I can...dig deeper.",
#  'L374936': 'Yeh.',
#  'L47726': "The Delta closes off to us about ten  miles out of Hau Fat. We'll be able to pick up some supplies -- bit I think there are only two points we can draw enough water to get into the Nung River. It's all Charlie's turf from there on out.",
#  'L67439': 'Yes, you did.  They never tested you, did they?  But Internal Affairs knew.',
#  'L36163': 'No, you demand results. They are not the same thing. And if you want results, you will let me do my job as I see fit. Unless of course,  You want this fool to saddle up and take another run at it?',
#  'L488680': "All right, since I got you on the phone, let's talk about your character.",
#  'L222598': 'Do you know this man? Is there something between you?',
#  'L297141': 'Elena.',
#  'L354991': "He won't.",
#  'L28078': "Don't get up. And please stop acting as if I were the queen mother.",
#  'L227205': "I don't care about being hip anymore.",
#  'L96898': "You really do hear a lot, don't you?",
#  'L318244': 'Kaboom.',
#  'L465879': "A undercover cop has got to be Marlon Brando. To do this job you got to be a great actor. You got to be naturalistic. You got to be naturalistic as hell. If you ain't a great actor you're a bad actor, and bad acting is bullshit in this job.",
#  'L6535': "It's been six years.",
#  'L453038': 'Oh, ve come vit you.  All for one and all in the light.',
#  'L114226': 'Dead Cat!',
#  'L612734': 'Quiet!',
#  'L431294': "Baseball bats that's just for openers. They'll put the muscle on you, turned-around collar or no turned-around collar.",
#  'L469908': "Inventin' jokes ain't easy.",
#  'L202339': 'No, shes not.',
#  'L434161': "I don't know -- the gym, the fights. I <i>know</i> he don't miss the fights.  Having some tomorrow night at the State Theater.  He use to take me.",
#  'L568676': "I can't write and I can't spell. That's the privilege of a first-class education. You're upstairs at the back. I think Ermelinda made the bed up.",
#  'L82676': 'Oh, be still my heart.',
#  'L192505': 'The Force runs strong in the Skywalker line.  You will achieve great power ... Come, join with me!  Together we will be the most powerful ... even stronger than The Emperor.',
#  'L62035': 'Nah, I got me a job.',
#  'L308236': "It's okay.",
#  'L112678': 'Sleeping in the back.',
#  'L594666': "Charlie wasn't drunk last night.",
#  'L566478': 'Please. And you\'re sweating him? You\'re "all that" and you\'re sweating some lawn jockey?',
#  'L620407': 'Bob?',
#  'L459733': "I don't mean that the way it sounds.  Imagine it, a book. And I used to know you personal way back when.  Tell me something, Buddy, how do you dream up all that stuff?",
#  'L292135': 'A few years older, perhaps.',
#  'L290177': 'Tickets for what?',
#  'L58471': 'Looking for something -- someone.',
#  'L551378': "This piece of puke hired me to kill you, baby.  Do you believe that? Isn't that right, Tran?  You pinhead.",
#  'L525844': 'What?  What are you talking about?',
#  'L308518': 'Make it three hundred. And throw that in, too.',
#  'L413504': "That feller's just achin' to settle down with some nice woman and make a home for himself.",
#  'L338699': "It's a hundred leagues from here.",
#  'L547603': "We're out of money.",
#  'L101138': "It's alright.  If you want to go home...",
#  'L456901': "You asked my name once; it's Madeleine.",
#  'L518283': 'She has materialized from your memory of her.  What was her name?',
#  'L239171': 'Now if you don\'t want to be the --  -- fifth person ever to die in meta-shock from a planar rift, I suggest you get down behind that desk and don\'t move until we give you the signal "Stabilize -- All Clear."',
#  'L282183': 'You are not dead, boy.  Accept it.',
#  'L219489': 'Margaret.',
#  'L205389': "Removal Point? What're you talking about!",
#  'L176758': 'Ed... I think we should stop seeing each other.',
#  'L589582': 'What time is it?',
#  'L302723': "We'll change your appearance.",
#  'L347467': "Hook's on 24...",
#  'L575616': "It's OK.",
#  'L30075': 'Ui-vol-i-tub!',
#  'L566317': "That's bullshit.",
#  'L355071': "We don't share our lives the way a lot of people do.",
#  'L228150': 'You like the car?',
#  'L62999': 'Helsinki, which is the capital of Finland.',
#  'L184283': 'Why Picton?',
#  'L318333': "I'm stuck!",
#  'L92952': "What's fair?",
#  'L555077': 'You send them.  Is that it, Max?',
#  'L259400': "Due to Mr. Gill's untimely demise and everything, I guess you two will have to improvise the next round.",
#  'L609791': "Where is it?  Where'd it go?",
#  'L81285': "I'm sorry to say that our time is running short, but before we close, I'd like to ask one final question. What sort of gardener, sir, would you be?",
#  'L306983': "I'm clean with the IRS. I've reported every dollar I've ever made. Try again, girlfriend.",
#  'L86671': "I'm dealin' with what God put before me.",
#  'L152153': "Ah, Doolittle, I do have a malfunction on this readout, but I can't seem to pinpoint exactly where it is.",
#  'L459931': 'Buddy, that was pretty snotty of you, pushing me away like that just when it was interesting.',
#  'L245782': 'Do you have interests or control over gambling and narcotics in the state of New York.',
#  'L475225': "If you need me, I'll be --",
#  'L596455': 'Huh?',
#  'L278351': 'John, I know all about it.',
#  'L47119': "I hate to disturb you, but something came up -- it's rather important -- and I think it would be a good idea if you could see me -- at the apartment -- as soon as possible.",
#  'L141888': 'Tell me about it.',
#  'L469925': "It don't matter. It's my reputation. These guys think they can get off light. It's bad for my reputation -- It's bad for business. See ya killer.",
#  'L451775': 'Try ruling the world sometime.',
#  'L636036': 'Weapons. Misdemeanor two.',
#  'L304028': 'I believe that? Yes, I believe that.',
#  'L652906': 'Well, like kill him with the atomic bomb?',
#  'L127515': 'Jody. Wait.',
#  'L35595': 'Some Indian tracker you turned out to be, Tom.',
#  'L377606': 'So who are you saying he was?\t\t\t\t\t*',
#  'L221774': 'To quarter-horses.',
#  'L422171': "She'll be all right?",
#  'L249537': "I don't know yet.",
#  'L462201': 'He has a knife.',
#  'L268125': "And you, Colonel?  Let me guess: You don't know.",
#  'L393147': 'Oh--a wonderful thing--yes. Get you right in the mood--yes--yes.',
#  'L575172': "I know that.  But as time went on ... well, it <u>wasn't</u> a joke, was it?  She had a feeling about it -- about the last job -- how long I'd get the hook for.  Said she wouldn't be there this time when I got out.",
#  'L119249': 'Yes, Victor, I was.',
#  'L251358': "I'm trying to think of where there's a place to have a drink around here.",
#  'L655104': 'We have to stick with the plan.',
#  'L72670': "Join you?  I've spent my life trying to protect plants from extinction and now you corrupt my research into some maniacal scheme for world domination. When I get through you won't be able to get a job teaching high school chemistry, do you hear me, you psycho?",
#  'L222640': 'Soon?',
#  'L308547': "No, this is the safe sun.  It's better than a day at the beach.",
#  'L183989': "No sand.  That's your drugs speaking.",
#  'L360308': 'I said no touching.',
#  'L566803': 'You dick.',
#  'L110877': 'Oh, right ...',
#  'L600517': "Guilty as charged. I'm not gonna play games with you. I could give you a song and dance but what's the point? I did it and we all know it.  The hitcher himself told me it's illegal. The irony...",
#  'L81111': 'Nonsense, Mr. President - I thank you for coming to spend time with a dying man.',
#  'L145998': "But what about Beast?   Who'll...?",
#  'L346408': 'Anything left for smashing you may happily smash.',
#  'L338317': 'Fame.',
#  'L585961': "Just a little... What's the difference?",
#  'L29156': "Isn't that what you'd expect them to say?",
#  'L601602': "At the finish, it's Single Action by two, Fasanella second, Visitation third.  Line on Single Action... 3 to 2. Hell with it, that's no good.",
#  'L157258': "But father, I'm assistant editor.",
#  'L190249': "Don't joke.  They might.  So do me a favor and behave yourself for once.  Ed Masry to see Kurt Potter.",
#  'L345401': 'Margot!',
#  'L569384': 'Physical? Criminal?',
#  'L443990': "Here, kid, this is great stuff.  Why don't you give it a try?",
#  'L241793': 'Same rules for everyone, sir.',
#  'L146350': 'So there were no problems?',
#  'L38854': "So's Woody Allen.  No, your uncle really helped me. I was sort of messed up for a while. Wasting my time just partying and... just stupid shit. He kind of woke me up, gave me a job, got me taking classes.  You know, he and Claude, their work is controversial, but they're serious about it. Totally dedicated.",
#  'L57547': "Ah ... From Trubshaw's.  My shoemaker.",
#  'L140512': 'Why?',
#  'L230958': "We only make wild speeches, or perform even wilder acts of terrorism. We've bred an army of anarchists but not one single group that can really fight the British anywhere.",
#  'L13845': "You must have tons of questions. You may smoke if you want to. Just don't tell any of the Sisters.",
#  'L183635': 'What if--',
#  'L521588': 'Complete washout.',
#  'L433893': "But don't you <u>do</u> anything.  You just have a seat, wait for me to get there.",
#  'L406198': 'She will probably appear with a dozen excuses and you will forgive her anyway.',
#  'L155580': 'Wrong...',
#  'L202781': 'Uh huh. The retail end, I understand.',
#  'L99238': 'You must have some feeling.  Some immediate impression.  A young, attractive woman, involved with an older man who leaves her everything in his will.  And the things that went on in that house.  Such wild sex.  What kind of picture does that paint?',
#  'L320394': 'Probably.',
#  'L406401': 'What I am talking about is moderation.',
#  'L589399': "No. Here's fine. ",
#  'L628508': "Where's that?",
#  'L525075': 'Kyle?!',
#  'L506351': 'Things are getting messy around here.  I hear Ezra Johnson got himself killed.',
#  'L601792': 'Four!',
#  'L589064': "What's in this? Nitro-glycerin?",
#  'L108708': "I don't know.",
#  'L648313': "Harvey says he's amazing.",
#  'L296658': "I'm fine dad.",
#  'L58102': 'Spoil the majority shareholders. In Wonderland Weather. I planned everything, even the Ministry recruiting you ...',
#  'L402887': "No sweetheart, you can't.",
#  'L641152': "I don't know...",
#  'L588718': "I've been wanting a cigarette for the past twenty minutes, but I couldn't convince myself to stop. This 'tilling of the soil' can get a little compulsive, you know.",
#  'L96856': 'It must be great.',
#  'L401983': "It'll end. It'll end with him and McCay. Then the park shuts down. Permanently.",
#  'L175318': 'Edward Wood, Sir.',
#  'L219968': 'She moved out.',
#  'L166742': "You're goin' outside with me.  If there's no cops around, we just split.  Otherwise, you go with us.",
#  'L296845': 'What do you think?',
#  'L572962': "Where'd you get that... ?",
#  'L409852': "I guess I'll rob a bank.",
#  'L135059': 'Can I trouble you for one of those magazines?',
#  'L502891': "I can't really remember.",
#  'L227061': 'So, are you having fun yet?',
#  'L518225': 'I want to hear your version.',
#  'L475464': "Looks like some kind of drug deal or something, they're not from around here --  one of them's still alive.",
#  'L620798': 'Lemme ask you a question.  Ever fuck a mutant?',
#  'L282703': 'Leave her alone.',
#  'L482379': 'Who is it?',
#  'L236249': 'Yeah. Fine. I just thought I heard something is all.',
#  'L85442': 'No Dude.',
#  'L67261': "No.  I said I liked Johnny to use his hands.  I don't give any rules, Nick.  I go with the flow.",
#  'L623705': "I'm a fugitive from the law. I can't be seen on the fucking streets. Now watch my lips. Kempton Park. Two-thirty. Five pounds to win. Bad Boy.",
#  'L566947': 'It is on.',
#  'L499221': 'I hear you have a new play for the Curtain.',
#  'L234333': 'Wire pull over?',
#  'L226810': "I'm gonna get your outta this.  Just hang tight.  Okay?",
#  'L521935': "I don't care.",
#  'L299511': 'How dare he?!',
#  'L115095': "Kimberly, it's the senior dance.",
#  'L245598': 'How is your wife, Fredo...your marriage?',
#  'L62421': 'Maybe.',
#  'L207086': 'Hey, Mike?',
#  'L298743': "We're already over Mach 2!",
#  'L310734': "Compared to you, my friend, Shapeley's an amateur.  Whatever gave you an idea you can get away with this! You're positively the most conceited",
#  'L346774': 'Take...',
#  'L596760': 'Yes. Im trying to reach a friend but I cant get through. The number is 01766 770 471.',
#  'L230363': 'This could be it.',
#  'L564698': 'Abbott and I used to do a lot of that in the spring.',
#  'L147849': 'Did you see who posted it?',
#  'L128487': "Shut up, shut up!  It's beeping.",
#  'L290558': "What's he so excited about?",
#  'L421538': "There'll be time for that.",
#  'L623403': 'Mr. Murphy, {leaving your friend aside,} do you see yourself as having any weaknesses?',
#  'L414131': 'Them kids!',
#  'L545011': 'Within you are memory patterns of a carbon unit. If I can help you revive these patterns; you could understand our functions better.',
#  'L395948': 'Oh, hello darling.',
#  'L610113': 'I...I never killed anyone before.  I told you that.',
#  'L507327': "You understood them.  That's what was amazing.  It's a nice day.  Let's eat outside.",
#  'L144712': "Hello, Ruben...  So that's that...",
#  'L542678': 'Good.',
#  'L356594': "Oh... that's nothing, someone gave it to me.",
#  'L635645': "I'll bet anything he won't go to town nor he won't ride out on the range. Right off he'll hole up at the ranch.",
#  'L197049': 'I am a fighting man and I am married to the quest. That is enough.',
#  'L431269': 'Maybe I will one of these days.',
#  'L481843': "With Ramn it's ... pride. I spoke out of the bitterness in me. And he was hurt.",
#  'L427005': "What's stopping you?",
#  'L440785': 'I dove back into work, everything was fine. Until the lesions started...',
# ...
#  'L144245': 'My third grade teacher at the convent shot better than that.',
#  'L426308': "Well now, I don't believe assa property scription.",
#  'L151740': "Frida? I hear you talking. I know you're in there. Let me in.",
#  'L451700': 'If we surrender, and I return with you, will you promise not to hurt this man?',
#  'L256035': "A future. The only future I've got.",
#  'L244515': 'I just put Jim into Black Creek...are you acquainted with...',
#  'L431407': "Even pigeons aren't peaceful.",
#  'L555078': "I'd better press your evening clothes, sir.  You have not for- gotten Madame's New Year's party.",
#  'L580246': 'The Federal Building was too well guarded.',
#  'L419657': 'Well, there were two Scotchmen. One was named McIntosh and one was named McGillicuddy. They met on the street.',
#  'L463560': "No, I think that's just oranges. She writes here she's eating oranges.",
#  'L154900': 'This is mine, Al -- all mine ... I made him. I built him.  And no cocksucker is gonna come in here and take it away from me just because he to be Vice President of the United States!',
#  'L378999': 'What are you talking about? This is it. This is the stuff right here.  Well, maybe just a pinch more sugar.',
#  'L329851': "Why do people think yellow is gender- neutral? I don't know one man with a yellow bedroom.",
#  'L465837': "Your name's Freddy something.",
#  'L332395': "I think we're lost.",
#  'L37010': 'Have you consulted a psychic?',
#  'L306325': 'My client feels sufficiently dispassionate.',
#  'L587646': 'Zackly.',
#  'L330099': 'It does?',
#  'L169598': "He's right.",
#  'L250188': 'Oh, right.',
#  'L406475': 'My regrets, my dear Major, but I believe you have been blocking the road.',
#  'L554996': "I'm talking to you.  My clothes and things are up in the room.",
#  'L354755': 'Tipico.',
#  'L83557': "What you want'em for?",
#  'L236051': "I don't know what you're talking about?",
#  'L347552': 'Shut up, all of you.',
#  'L135258': 'You open?',
#  'L377516': 'What the fuck are you doing here?',
#  'L509593': "I'm going to transfer you. I know two psychologists that are exceptional--",
#  'L219421': 'Frank, you look a little peaked. Wanna vomit?',
#  'L327180': "He's asleep, right?",
#  'L435620': 'If you got something to say, say it.',
#  'L326305': 'You got a warrant for this?',
#  'L145492': 'Outside in the visitors, car park.',
#  'L343992': 'Yes. One of my friends was there. I wonder if you ever clipped her.',
#  'L309208': "It doesn't look much like the fish spears I knew back in Marblehead..",
#  'L308141': "Nah. I'll probably just be here studying for finals. The joys of summer school...  Are you okay?",
#  'L10599': 'But how could you say such a thing?',
#  'L202936': 'You were supposed to be here half an hour ago...the emergency strategy session? Your trip to Aspen? Theyre all panicked here...',
#  'L636498': "If I'm going in, I want a stake.",
#  'L429102': 'Yes, Miss Ratched!',
#  'L622225': 'Stop it!',
#  'L665175': "No, I guess I've been no help at all to you.",
#  'L662482': 'Know what?',
#  'L93924': "It's taken care of. The less you know about it the better.",
#  'L48355': 'Flood.',
#  'L289334': 'The Americans, and the UN they have you as a war criminal. You are on a list.',
#  'L99994': 'What do you have in your purse?',
#  'L342725': 'You forget yourself!',
#  'L313933': "I'm getting out of here. What do you think?",
#  'L195966': "It's possible that a burst of gravity waves escaped from the Core, distorting space-time. They could be what hit the Lewis and Clark.",
#  'L31684': 'Shall I be forced to feed you, David?',
#  'L424004': "You know, the more I think about it, this really isn't David's kind of place.",
#  'L255222': "She'll be awright.",
#  'L502540': 'No.',
#  'L149885': "Alright, I believe you. Stop crying. Your secret's safe with me.",
#  'L462809': 'You promised to give it back.',
#  'L300499': 'Legend says that when the stones are brought together the diamonds inside of them will glow.',
#  'L400952': 'How?',
#  'L439898': "Be good to your mother, darlin'. She needs you.",
#  'L586000': "Yes. It's very pleasurable. But the Jews are obsessed with it. You know why?",
#  'L660951': 'The guy on the phone.',
#  'L160852': 'Hey, Nick, you ever do it with one of those slants?',
#  'L366369': 'Being black, is that a positive or negative for a bodyguard in Mexico?',
#  'L402923': "I'm not asking you to stop feeling for those people. But life isn't just death Harry, don't ignore the living, especially your daughter.",
#  'L267590': 'Behind a desk for a little while.  A desk!  They had him planning air raids.  A city can\'t flee like a coward or fight like a man, and the choice between fleeing and fighting was at the core of the life of Harold Ryan.  There was only one thing he enjoyed more than watching someone make that choice, and that was making the choice himself.  Ask about Spain, where he was the youngest soldier in the Abraham Lincoln Brigade.  He was a famous sniper.  They called him "La Picadura"--"the sting."',
#  'L289073': 'Go out! Where?',
#  'L249855': '285.',
#  'L265572': 'Well.  Word gets around.',
#  'L666361': 'Will you hear "Last Post", Sir?',
#  'L232802': 'Lafayette will not be happy...',
#  'L661639': 'Oh?',
#  'L553170': 'Sorry.',
#  'L130521': "C'mon, you think you're dealing with a bunch of assholes? Mulwray had salt water in his goddam lungs! Now how did he get that... in a fresh water reservoir?",
#  'L44938': "'Think I should buy some originals?",
#  'L556880': 'He really was!',
#  'L180706': 'Pardonnez-moi, I cannot tell vat is "like me".',
#  'L502746': "I'd be glad to do that, sir.  Oh why don't you call me back in about eh twenty minutes?",
#  'L369118': 'Could he handle a direct contact?',
#  'L364315': "I ain't drinking hot piss with you. Come on, Sam.",
#  'L172457': "That's funny, we've got five thousand horses but no men.",
#  'L38876': "Claude, it's Andy, he's acting really weird, I think something happened last night...",
#  'L304479': "He's into kind of little cars, that...",
#  'L422019': 'Yeah. I was in Nam.',
#  'L665805': 'Better not get too close, master. This guy could kill you.',
#  'L456842': 'I pray you: be succinct.',
#  'L511564': 'She did not do it... please listen...',
#  'L587538': '... Push me back in the water...',
#  'L126644': 'No -- I guess not.',
#  'L219785': 'In her cabana, sir.',
#  'L388016': "You know we had reservations about each other.  Isn't it a little late in the day to be asking me that?",
#  'L310442': "Absurd!  All this fuss over a snip of a girl.  I'm going down to see her myself.",
#  'L192072': 'Much anger in him, like in his father.',
#  'L388505': 'In downtown Sydney for a start.',
#  'L191889': 'I want that ship.',
#  'L191937': "But we're going to get pulverized if we stay out here much longer.",
#  'L140843': 'Well, this is just fucking great...',
#  'L421100': "Is that adjusted for inflation?  Think of the life Mao's led.  In '52 I called him a monster.  Now he could be our most important ally.  Only Nixon could've done that.",
#  'L195683': 'What is that?',
#  'L253217': 'Not now.',
#  'L657310': "Don't make me angry, Peck.",
#  'L636494': "Doubtful. With all that coke, they'll be ready - which brings me to sunny spot number two. Even if one of us gets through and jacks the boat, we get nothing.",
#  'L383788': "I don't hear you bitch about the money.",
#  'L124335': 'Naturally.',
#  'L58238': "I. Don't. Dance.",
#  'L611613': 'Who did?',
#  'L406403': 'And where do you place Alexander?',
#  'L342325': "Stacy, did Fredrica ever mention a man named Jamie Gumb? Or John Grant?  Do you think she could've had a friend you didn't know about?",
#  'L565402': "I don't believe it.",
#  'L228899': 'Friend. You stole all my best lines.  You cut me out of episode two entirely!..',
#  'L205461': "That blip we're picking up might only be the radio-active particle. The Proteus may already be destroyed...",
#  'L626763': 'In those days, they often worked as a team.',
#  'L648762': 'Jody, she tried to kill him.',
#  'L391165': 'Well, what do you wanna talk about!',
#  'L395319': 'Now, where were we?',
#  'L219091': 'What?',
#  'L93463': "Yes, ma'am.",
#  'L60818': "Oh God, Stephen, what's going on with you?",
#  'L508832': "I've got a show -- at St. Matthew's Cathedral.  We're singing for the Cardinals.",
#  'L664806': "We're on to the game, ese. You got the fake blood splattered all over the walls, you got your torture tools... It's all very cute. But come on, let's quit while you're ahead. I'm only trying to save you a beatin'.",
#  'L144849': "She is a writer, writing best selling books about serial killing. Giving lectures she's well-paid for.  Her interests are not the interests of law enforcement.",
#  'L388215': 'Affirmative.',
#  'L523371': "He beat you, too, Daddy, and you had a big ol' shootin' rifle.",
#  'L411518': 'If you say so.',
#  'L550433': 'Yes, Mikey?',
#  'L201008': "You're wearing your suit --",
#  'L636594': "He used all of you to get him on that boat. He couldn't get on alone and he had to pull the trigger himself to make sure he got his man. The one man that could identify him.",
#  'L579021': "That's correct.",
#  'L502462': 'Yeah.',
#  'L66781': "I wouldn't know where to start.  I guess it was about one man framing another. He thought if the other guy got blamed, people would over look his own wrong doings.",
#  'L55433': 'A lot of people think like that.',
#  'L278324': "What, is everybody in love with this, bozo?  I don't get this.  What about...?",
#  'L354680': 'Suppose not.',
#  'L525861': "Well blaze your ass out of there! You've completely altered your trajectory, are we linking up or not?!",
#  'L45260': 'Hmm?',
#  'L475665': "Besides, I'm not stupid, Earl. The tape was a basic Maxell D-80.  You can buy 'em at any store.  There's no way they can pin anything on me.",
#  'L294984': "You better believe they're dirty! And smelly! And messy! And they don't know their forks from their assholes!",
#  'L644813': '...Work okay?',
#  'L194241': 'No, stay. Just for a little while.  Refill?',
#  'L369122': "If the Tooth Fairy listens to Lecktor, he'll come for me. So we're going to set me up as bait to draw him out. Give him a clean shot.  That's what you were thinking, isn't it?",
#  'L349105': "I'll ask.",
#  'L649376': 'I was born, in New Orleans, too-',
#  'L336386': "He's got an answer for everything, but he doesn't have an alibi.",
#  'L51785': "I just love her.  How're you doing?",
#  'L651220': "Each one of you will be responsible for one student.  I'll expect you to be courteous.  You represent this school and your country.  We'll sail in the morning.",
#  'L431558': "And don't be walking off with any of that. You know how the boss feels about individual pilferage.",
#  'L154563': 'Oh, yeah?',
#  'L591662': 'Hi Mom!',
#  'L124878': 'You stupid bastard --',
#  'L247942': 'What for?',
#  'L600563': 'Shoot.',
#  'L332564': "And we're in the center ring.  You sure you want to wear that blazer?",
#  'L553357': 'You do not!',
#  'L253685': "Never mind -- I'll get it. I have a whole day. I'll be on that train.",
#  'L68450': 'Should there be?',
#  'L237104': "Don't worry.",
#  'L216217': 'What do you call that?',
#  'L28700': 'Something simple. A fur coat over a nightgown...',
#  'L279466': 'Just the obvious stuff.',
#  'L642352': "Parents? Nobody cares a damn, what's the use of them!",
#  'L127846': "Some people might say you're readin' an awful lot in-...",
#  'L571224': 'Probably.  Sarah, if I get zeroed...',
#  'L57851': 'Nature ...',
#  'L618547': "It's Bond!",
#  'L131347': 'When they watched at all. Do you like movies?',
#  'L589210': 'After the gulls attacked.',
#  'L138125': 'Hi. Hi. Hi, there my Pee and Em. All three look up startled.',
#  'L48570': "I'll never get over it -- But I'll always remember him...",
#  'L553339': "No, no, it isn't. It's cool.",
#  'L646416': 'Good evening sir.',
#  'L213477': "Please understand... I've gotten all I can from this, Tyler.",
#  'L315987': "There's something I've gotta take care of, Louis.",
#  'L616327': 'I saw him take the bracelet out of that shoe.',
#  'L591995': "I think I'm very lucky. You don't always get a chance to recognize a mistake before you make it.",
#  'L860': 'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'L342070': "If you didn't want me chasing him, you shouldn't have taken me to that funeral home.",
#  'L347565': "It's Sixpack!",
#  'L289132': 'A kiss.',
#  'L160839': 'No.',
#  'L64767': 'You are a Hungarian; you served in the army, and left on account of weakness in the loins.  He gambles a great deal, and wins.  Do you know the cards well?',
#  'L369087': 'What kind of coffee do you like?',
#  'L99959': "Why didn't you come to me?",
#  'L324630': 'They put bombs on dolphins....',
#  'L250214': "Can I ask you a favor, can we do this at Sean's from now on? 'Cause I leave work to come here and the fuckin' commute is killin' me--",
#  'L88195': 'What?',
#  'L150527': 'No. Amy slapped Donald because he had hurt the butterfly -- and it was her friend.',
#  'L255822': "Come on, Myra, don't talk business here. This is time out.",
#  'L665984': 'Are you suggesting I call him master???',
#  'L527243': 'That far in what, Harry?',
#  'L319337': 'Right.',
#  'L117555': "Ebby Calvin Nuke LaLoosh--don't think too much.",
#  'L527608': 'About the time paradox.  How we were all going to die -- that there was no way we would make it out of here alive --',
#  'L534126': 'Admiral --',
#  'L126694': 'Why?',
#  'L486741': "What's that?",
#  'L58216': 'About your next assignment, Mrs. Peel ...',
#  'L653285': "Why not? How was the fishin'?",
#  'L483656': 'Lloyd.',
#  'L260477': "No way! Halloween's great. Can we stay out all night?",
#  'L47110': "Maybe we should send up two flies -- and see if they'll propagate in orbit.",
#  'L513698': 'Bill, we need to talk!',
#  'L407395': "I've got a gig tonight.",
#  'L60725': 'Cook and I are almost finished here. Have a seat.',
#  'L597572': 'Rich. Young. Beautiful. You must at least get a kick out of what he does to his kids.',
#  'L213164': "It's what he would have wanted, sir.",
#  'L434009': 'And the guy sent you a bill for this?',
#  'L438533': 'You were always friendly to me. I appreciated that.  You know, this used to be a fantasy of mine.',
#  'L430514': 'Oh.',
#  'L101579': "Still bickerin' over that, huh?",
#  'L464344': "DROP 'EM! DROP, DROP, DROP!!!",
#  'L504373': 'Ooooh, now the cards are on the table.',
#  'L8420': "It's okay, Dan",
#  'L521553': 'Caught him off Cape Hatteras.',
#  'L377109': "She's gone and the present is trivia, which I can scribble down as notes.",
#  'L665906': 'Thanks...for all your help.',
#  'L522387': 'Claire...!',
#  'L381648': "Oh. Right.  I guess that's kind of cool, too, in it's own way.  Course, this isn't really black; it's kind of a dull, dirty, tarry sort of noncolor, isn't it?",
#  'L267296': 'What?',
#  'L587782': "Give the man a hug, boy!  That's your father!",
#  'L402790': "I do, she's real funny.",
#  'L377592': "But he's not the right guy!\t\t\t\t\t  *",
#  'L600354': 'That sneaky prick was probably practicing his jai alai.',
#  'L306979': 'I want to nail you ass.',
#  'L361024': 'Nah, man...',
#  'L375796': 'The jacket and the pair of pants came with the body I took.  Let me ask your opinion.  Do I blend in?',
#  'L602523': "Tch-tch-tch --  Well, goodbye, Miss Wynant.  You wouldn't drive slowly, so you don't get a tip.",
#  'L638871': 'Oh?',
#  'L311221': "I haven't changed my mind, Westley, I want you to understand that! I don't like you! I never have!  I never will! That's clear enough, isn't it?",
#  'L649584': 'You kept her in this filth in restraints...?.',
#  'L501164': 'My secretary saw you with that boy.',
#  'L431510': "You know what you're askin'? You're askin'",
#  'L587296': 'Way past it.',
#  'L524739': "Is it Cartman's mom?",
#  'L577617': "I'll go.",
#  'L304399': 'Alright... the ABC Telemarketing Company?',
#  'L472634': "And you could stand to get a little smarter, ain't that right you dumb blonde fuck?",
#  'L26525': 'Poor bastard.',
#  'L438962': 'Where have you been?',
#  'L213250': 'You broke your promise.  You talked to her about me.',
#  'L255523': "That's right.",
#  'L648098': "Beautiful thing, alimony.  Lose a husband, get a car.  Think it'll help me pick up dudes?",
#  ...}

# %%
conversations_ids=[]
for conversation in conversations[:-1]:
    _conversation=conversation.split(" +++$+++ ")[-1][1:-1].replace("'","").replace(" ","")
    conversations_ids.append(_conversation.split(","))

# %%
conversations_ids
# Out:
# [['L194', 'L195', 'L196', 'L197'],
#  ['L198', 'L199'],
#  ['L200', 'L201', 'L202', 'L203'],
#  ['L204', 'L205', 'L206'],
#  ['L207', 'L208'],
#  ['L271', 'L272', 'L273', 'L274', 'L275'],
#  ['L276', 'L277'],
#  ['L280', 'L281'],
#  ['L363', 'L364'],
#  ['L365', 'L366'],
#  ['L367', 'L368'],
#  ['L401', 'L402', 'L403'],
#  ['L404', 'L405', 'L406', 'L407'],
#  ['L575', 'L576'],
#  ['L577', 'L578'],
#  ['L662', 'L663'],
#  ['L693', 'L694', 'L695'],
#  ['L696', 'L697', 'L698', 'L699'],
#  ['L860', 'L861'],
#  ['L862', 'L863', 'L864', 'L865'],
#  ['L866', 'L867', 'L868', 'L869'],
#  ['L870', 'L871', 'L872'],
#  ['L924', 'L925'],
#  ['L984', 'L985'],
#  ['L1044', 'L1045'],
#  ['L49', 'L50', 'L51'],
#  ['L571', 'L572', 'L573'],
#  ['L579', 'L580'],
#  ['L595', 'L596', 'L597'],
#  ['L598', 'L599', 'L600'],
#  ['L659', 'L660'],
#  ['L952', 'L953'],
#  ['L394', 'L395'],
#  ['L396', 'L397'],
#  ['L589', 'L590', 'L591'],
#  ['L592', 'L593'],
#  ['L756', 'L757', 'L758'],
#  ['L759', 'L760'],
#  ['L164', 'L165'],
#  ['L319', 'L320'],
#  ['L441', 'L442', 'L443', 'L444', 'L445'],
#  ['L525', 'L526', 'L527'],
#  ['L529', 'L530'],
#  ['L531', 'L532', 'L533'],
#  ['L542', 'L543'],
#  ['L601', 'L602'],
#  ['L655', 'L656'],
#  ['L889', 'L890', 'L891', 'L892'],
#  ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900'],
#  ['L901', 'L902', 'L903'],
#  ['L904', 'L905', 'L906', 'L907', 'L908'],
#  ['L909', 'L910', 'L911', 'L912', 'L913', 'L914'],
#  ['L982', 'L983'],
#  ['L1007', 'L1008', 'L1009', 'L1010', 'L1011'],
#  ['L1021', 'L1022'],
#  ['L1051', 'L1052'],
#  ['L179', 'L180', 'L181', 'L182', 'L183'],
#  ['L189', 'L190'],
#  ['L517', 'L518', 'L519', 'L520', 'L521'],
#  ['L523', 'L524'],
#  ['L536', 'L537'],
#  ['L538', 'L539', 'L540'],
#  ['L544', 'L545', 'L546'],
#  ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884'],
#  ['L922', 'L923'],
#  ['L458', 'L459', 'L460', 'L461', 'L462', 'L463'],
#  ['L63', 'L64', 'L65'],
#  ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74'],
#  ['L77', 'L78'],
#  ['L87', 'L88', 'L89', 'L90', 'L91', 'L92'],
#  ['L139', 'L140', 'L141', 'L142'],
#  ['L143', 'L144', 'L145', 'L146', 'L147'],
#  ['L157', 'L158', 'L159'],
#  ['L210', 'L211'],
#  ['L212', 'L213'],
#  ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222'],
#  ['L223', 'L224', 'L225'],
#  ['L244', 'L245'],
#  ['L388', 'L389', 'L390', 'L391'],
#  ['L416', 'L417', 'L418', 'L419'],
#  ['L424', 'L425'],
#  ['L432', 'L433'],
#  ['L499', 'L500'],
#  ['L583', 'L584', 'L585', 'L586'],
#  ['L778', 'L779'],
#  ['L385', 'L386'],
#  ['L411', 'L412'],
#  ['L426', 'L427'],
#  ['L430', 'L431'],
#  ['L619', 'L620'],
#  ['L621', 'L622'],
#  ['L623', 'L624', 'L625'],
#  ['L725', 'L726'],
#  ['L740', 'L741'],
#  ['L743', 'L744', 'L745'],
#  ['L780', 'L781'],
#  ['L148', 'L149', 'L150'],
#  ['L335', 'L336'],
#  ['L554', 'L555', 'L556'],
#  ['L557', 'L558'],
#  ['L285', 'L286'],
#  ['L287', 'L288', 'L289', 'L290', 'L291', 'L292'],
#  ['L294', 'L295', 'L296', 'L297'],
#  ['L298', 'L299'],
#  ['L300', 'L301'],
#  ['L349', 'L350', 'L351', 'L352'],
#  ['L354', 'L355', 'L356', 'L357', 'L358'],
#  ['L605', 'L606'],
#  ['L607', 'L608', 'L609'],
#  ['L747', 'L748'],
#  ['L231', 'L232', 'L233', 'L234', 'L235', 'L236'],
#  ['L238', 'L239', 'L240'],
#  ['L502', 'L503', 'L504', 'L505'],
#  ['L508', 'L509'],
#  ['L123', 'L124', 'L125', 'L126', 'L127', 'L128'],
#  ['L129', 'L130'],
#  ['L131', 'L132'],
#  ['L133', 'L134'],
#  ['L151', 'L152'],
#  ['L247', 'L248', 'L249', 'L250', 'L251'],
#  ['L252', 'L253', 'L254'],
#  ['L447', 'L448'],
#  ['L490', 'L491'],
#  ['L716', 'L717', 'L718', 'L719', 'L720', 'L721'],
#  ['L750', 'L751', 'L752', 'L753', 'L754', 'L755'],
#  ['L946', 'L947', 'L948', 'L949'],
#  ['L304', 'L305', 'L306', 'L307'],
#  ['L309', 'L310'],
#  ['L311', 'L312', 'L313'],
#  ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328'],
#  ['L330', 'L331', 'L332'],
#  ['L333', 'L334'],
#  ['L473', 'L474'],
#  ['L475', 'L476', 'L477'],
#  ['L481', 'L482', 'L483'],
#  ['L564', 'L565', 'L566', 'L567'],
#  ['L610', 'L611'],
#  ['L612', 'L613', 'L614', 'L615', 'L616'],
#  ['L626',
#   'L627',
#   'L628',
#   'L629',
#   'L630',
#   'L631',
#   'L632',
#   'L633',
#   'L634',
#   'L635',
#   'L636'],
#  ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646'],
#  ['L650', 'L651'],
#  ['L668', 'L669'],
#  ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676'],
#  ['L677', 'L678', 'L679'],
#  ['L680', 'L681', 'L682'],
#  ['L683', 'L684'],
#  ['L686', 'L687', 'L688', 'L689', 'L690'],
#  ['L764', 'L765', 'L766', 'L767', 'L768'],
#  ['L769', 'L770', 'L771', 'L772', 'L773', 'L774'],
#  ['L798', 'L799'],
#  ['L800', 'L801', 'L802'],
#  ['L803', 'L804', 'L805', 'L806'],
#  ['L808', 'L809', 'L810', 'L811', 'L812'],
#  ['L813',
#   'L814',
#   'L815',
#   'L816',
#   'L817',
#   'L818',
#   'L819',
#   'L820',
#   'L821',
#   'L822',
#   'L823'],
#  ['L824', 'L825'],
#  ['L828', 'L829', 'L830', 'L831', 'L832'],
#  ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841'],
#  ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848'],
#  ['L852', 'L853', 'L854', 'L855', 'L856', 'L857'],
#  ['L936', 'L937', 'L938', 'L939', 'L940'],
#  ['L957', 'L958', 'L959'],
#  ['L960', 'L961'],
#  ['L973', 'L974', 'L975', 'L976', 'L977'],
#  ['L1031', 'L1032'],
#  ['L1033', 'L1034', 'L1035'],
#  ['L1040', 'L1041', 'L1042', 'L1043'],
#  ['L172', 'L173', 'L174'],
#  ['L184', 'L185'],
#  ['L338',
#   'L339',
#   'L340',
#   'L341',
#   'L342',
#   'L343',
#   'L344',
#   'L345',
#   'L346',
#   'L347'],
#  ['L986', 'L987', 'L988'],
#  ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997'],
#  ['L998', 'L999', 'L1000'],
#  ['L103', 'L104', 'L105', 'L106', 'L107'],
#  ['L108', 'L109'],
#  ['L1017', 'L1018'],
#  ['L728', 'L729', 'L730', 'L731'],
#  ['L732', 'L733'],
#  ['L735', 'L736', 'L737', 'L738'],
#  ['L371', 'L372', 'L373'],
#  ['L375', 'L376', 'L377'],
#  ['L378', 'L379'],
#  ['L380', 'L381', 'L382'],
#  ['L383', 'L384'],
#  ['L414', 'L415'],
#  ['L420', 'L421'],
#  ['L428', 'L429'],
#  ['L436', 'L437'],
#  ['L723', 'L724'],
#  ['L775', 'L776', 'L777'],
#  ['L59', 'L60', 'L61', 'L62'],
#  ['L257', 'L258', 'L259'],
#  ['L261', 'L262', 'L263', 'L264'],
#  ['L511', 'L512'],
#  ['L161', 'L162'],
#  ['L170', 'L171'],
#  ['L191', 'L192', 'L193'],
#  ['L876', 'L877'],
#  ['L886', 'L887'],
#  ['L917', 'L918'],
#  ['L926', 'L927'],
#  ['L929', 'L930', 'L931', 'L932', 'L933'],
#  ['L2170', 'L2171', 'L2172'],
#  ['L2173', 'L2174', 'L2175'],
#  ['L2176', 'L2177'],
#  ['L2179', 'L2180', 'L2181'],
#  ['L1989', 'L1990', 'L1991', 'L1992', 'L1993'],
#  ['L2005', 'L2006'],
#  ['L2010', 'L2011', 'L2012'],
#  ['L2014', 'L2015', 'L2016'],
#  ['L2019', 'L2020'],
#  ['L2022', 'L2023'],
#  ['L2024', 'L2025'],
#  ['L2027', 'L2028', 'L2029'],
#  ['L2030', 'L2031'],
#  ['L2274', 'L2275'],
#  ['L2522', 'L2523', 'L2524'],
#  ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984'],
#  ['L1985', 'L1986'],
#  ['L2118', 'L2119'],
#  ['L2121', 'L2122', 'L2123'],
#  ['L2318', 'L2319', 'L2320'],
#  ['L2471', 'L2472'],
#  ['L2473', 'L2474'],
#  ['L2537', 'L2538'],
#  ['L2539', 'L2540'],
#  ['L2290', 'L2291', 'L2292', 'L2293'],
#  ['L2421', 'L2422'],
#  ['L2423', 'L2424', 'L2425', 'L2426'],
#  ['L2429', 'L2430', 'L2431', 'L2432'],
#  ['L2127', 'L2128', 'L2129'],
#  ['L2130', 'L2131'],
#  ['L2439', 'L2440'],
#  ['L2484', 'L2485'],
#  ['L2500', 'L2501'],
#  ['L2541', 'L2542'],
#  ['L2547', 'L2548', 'L2549'],
#  ['L2550', 'L2551', 'L2552'],
#  ['L2103', 'L2104', 'L2105'],
#  ['L2106', 'L2107', 'L2108'],
#  ['L2109', 'L2110'],
#  ['L2281', 'L2282'],
#  ['L2286', 'L2287'],
#  ['L2295', 'L2296', 'L2297'],
#  ['L2299', 'L2300', 'L2301'],
#  ['L2463', 'L2464'],
#  ['L2465', 'L2466'],
#  ['L2467', 'L2468', 'L2469'],
#  ['L2237', 'L2238', 'L2239'],
#  ['L2248', 'L2249', 'L2250', 'L2251'],
#  ['L2253', 'L2254', 'L2255'],
#  ['L2256', 'L2257', 'L2258', 'L2259', 'L2260'],
#  ['L2341', 'L2342', 'L2343'],
#  ['L2393', 'L2394'],
#  ['L2409', 'L2410'],
#  ['L1942', 'L1943'],
#  ['L1947', 'L1948', 'L1949', 'L1950'],
#  ['L1951', 'L1952'],
#  ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962'],
#  ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969'],
#  ['L2037', 'L2038', 'L2039', 'L2040'],
#  ['L2041', 'L2042'],
#  ['L2045', 'L2046'],
#  ['L2132', 'L2133'],
#  ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139'],
#  ['L2140', 'L2141', 'L2142', 'L2143'],
#  ['L2144', 'L2145'],
#  ['L2525', 'L2526'],
#  ['L2531', 'L2532', 'L2533', 'L2534', 'L2535'],
#  ['L2071', 'L2072'],
#  ['L2073', 'L2074', 'L2075'],
#  ['L2076', 'L2077'],
#  ['L2079', 'L2080', 'L2081', 'L2082'],
#  ['L2085', 'L2086'],
#  ['L2279', 'L2280'],
#  ['L2456', 'L2457', 'L2458', 'L2459'],
#  ['L2277', 'L2278'],
#  ['L2328', 'L2329'],
#  ['L2331', 'L2332', 'L2333'],
#  ['L2345', 'L2346'],
#  ['L2347', 'L2348'],
#  ['L2386', 'L2387', 'L2388', 'L2389'],
#  ['L2154', 'L2155'],
#  ['L2157', 'L2158', 'L2159', 'L2160'],
#  ['L2164', 'L2165'],
#  ['L2490', 'L2491', 'L2492'],
#  ['L2064', 'L2065'],
#  ['L2196',
#   'L2197',
#   'L2198',
#   'L2199',
#   'L2200',
#   'L2201',
#   'L2202',
#   'L2203',
#   'L2204',
#   'L2205',
#   'L2206',
#   'L2207',
#   'L2208',
#   'L2209',
#   'L2210',
#   'L2211'],
#  ['L1930', 'L1931'],
#  ['L2112', 'L2113'],
#  ['L2115', 'L2116'],
#  ['L2376', 'L2377'],
#  ['L2414', 'L2415'],
#  ['L2417', 'L2418', 'L2419'],
#  ['L2460', 'L2461', 'L2462'],
#  ['L3380', 'L3381', 'L3382'],
#  ['L3383', 'L3384', 'L3385'],
#  ['L3392', 'L3393', 'L3394', 'L3395', 'L3396'],
#  ['L3459', 'L3460', 'L3461'],
#  ['L3464',
#   'L3465',
#   'L3466',
#   'L3467',
#   'L3468',
#   'L3469',
#   'L3470',
#   'L3471',
#   'L3472',
#   'L3473',
#   'L3474',
#   'L3475',
#   'L3476',
#   'L3477',
#   'L3478',
#   'L3479',
#   'L3480',
#   'L3481'],
#  ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489'],
#  ['L3490', 'L3491', 'L3492', 'L3493'],
#  ['L3496', 'L3497'],
#  ['L3545', 'L3546'],
#  ['L3059', 'L3060', 'L3061'],
#  ['L3089', 'L3090', 'L3091', 'L3092'],
#  ['L3093', 'L3094', 'L3095'],
#  ['L3096', 'L3097'],
#  ['L3158', 'L3159', 'L3160'],
#  ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166'],
#  ['L3167', 'L3168', 'L3169', 'L3170'],
#  ['L3177', 'L3178', 'L3179', 'L3180', 'L3181'],
#  ['L3300', 'L3301', 'L3302'],
#  ['L3305', 'L3306', 'L3307', 'L3308'],
#  ['L3309', 'L3310', 'L3311'],
#  ['L3313', 'L3314'],
#  ['L3315', 'L3316', 'L3317', 'L3318'],
#  ['L3329', 'L3330'],
#  ['L3514', 'L3515', 'L3516', 'L3517'],
#  ['L3045', 'L3046', 'L3047', 'L3048'],
#  ['L3049', 'L3050', 'L3051'],
#  ['L3055', 'L3056'],
#  ['L3062', 'L3063', 'L3064', 'L3065'],
#  ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214'],
#  ['L2797', 'L2798', 'L2799', 'L2800'],
#  ['L3196', 'L3197'],
#  ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203'],
#  ['L3293', 'L3294'],
#  ['L3498',
#   'L3499',
#   'L3500',
#   'L3501',
#   'L3502',
#   'L3503',
#   'L3504',
#   'L3505',
#   'L3506'],
#  ['L2801', 'L2802', 'L2803', 'L2804', 'L2805'],
#  ['L3289', 'L3290', 'L3291', 'L3292'],
#  ['L2599', 'L2600', 'L2601'],
#  ['L2602', 'L2603'],
#  ['L2630', 'L2631', 'L2632', 'L2633'],
#  ['L2751', 'L2752'],
#  ['L2920', 'L2921', 'L2922', 'L2923'],
#  ['L2924', 'L2925'],
#  ['L2936', 'L2937', 'L2938'],
#  ['L3016', 'L3017'],
#  ['L3022', 'L3023'],
#  ['L3027', 'L3028'],
#  ['L2964', 'L2965', 'L2966', 'L2967'],
#  ['L2971', 'L2972', 'L2973'],
#  ['L2975', 'L2976', 'L2977', 'L2978'],
#  ['L2979', 'L2980', 'L2981'],
#  ['L2986', 'L2987', 'L2988', 'L2989', 'L2990'],
#  ['L2730', 'L2731'],
#  ['L2746', 'L2747', 'L2748'],
#  ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882'],
#  ['L2883', 'L2884', 'L2885', 'L2886'],
#  ['L2887', 'L2888', 'L2889', 'L2890', 'L2891'],
#  ['L2892', 'L2893'],
#  ['L2895', 'L2896', 'L2897'],
#  ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906'],
#  ['L2949', 'L2950', 'L2951', 'L2952', 'L2953'],
#  ['L2955', 'L2956', 'L2957', 'L2958'],
#  ['L2962', 'L2963'],
#  ['L2991', 'L2992'],
#  ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999'],
#  ['L3052', 'L3053', 'L3054'],
#  ['L3057', 'L3058'],
#  ['L3067', 'L3068'],
#  ['L3069',
#   'L3070',
#   'L3071',
#   'L3072',
#   'L3073',
#   'L3074',
#   'L3075',
#   'L3076',
#   'L3077',
#   'L3078',
#   'L3079'],
#  ['L3080', 'L3081', 'L3082'],
#  ['L3219', 'L3220', 'L3221', 'L3222'],
#  ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228'],
#  ['L3229', 'L3230'],
#  ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242'],
#  ['L3243', 'L3244'],
#  ['L3248', 'L3249'],
#  ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765'],
#  ['L3029', 'L3030'],
#  ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037'],
#  ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044'],
#  ['L3101', 'L3102'],
#  ['L3103',
#   'L3104',
#   'L3105',
#   'L3106',
#   'L3107',
#   'L3108',
#   'L3109',
#   'L3110',
#   'L3111',
#   'L3112',
#   'L3113',
#   'L3114',
#   'L3115',
#   'L3116',
#   'L3117'],
#  ['L3119', 'L3120', 'L3121'],
#  ['L3126', 'L3127', 'L3128', 'L3129', 'L3130'],
#  ['L3135',
#   'L3136',
#   'L3137',
#   'L3138',
#   'L3139',
#   'L3140',
#   'L3141',
#   'L3142',
#   'L3143',
#   'L3144',
#   'L3145',
#   'L3146',
#   'L3147'],
#  ['L3148',
#   'L3149',
#   'L3150',
#   'L3151',
#   'L3152',
#   'L3153',
#   'L3154',
#   'L3155',
#   'L3156',
#   'L3157'],
#  ['L2595', 'L2596'],
#  ['L2604', 'L2605', 'L2606', 'L2607'],
#  ['L2611', 'L2612'],
#  ['L2644', 'L2645'],
#  ['L2646', 'L2647', 'L2648'],
#  ['L2651', 'L2652'],
#  ['L2653', 'L2654', 'L2655', 'L2656'],
#  ['L2664', 'L2665'],
#  ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626'],
#  ['L2627', 'L2628'],
#  ['L3278',
#   'L3279',
#   'L3280',
#   'L3281',
#   'L3282',
#   'L3283',
#   'L3284',
#   'L3285',
#   'L3286'],
#  ['L3419', 'L3420', 'L3421'],
#  ['L3431', 'L3432'],
#  ['L3433', 'L3434'],
#  ['L3435', 'L3436'],
#  ['L3554', 'L3555', 'L3556'],
#  ['L2845', 'L2846', 'L2847'],
#  ['L2848', 'L2849'],
#  ['L2850', 'L2851', 'L2852', 'L2853', 'L2854'],
#  ['L2855', 'L2856'],
#  ['L2857', 'L2858'],
#  ['L2563', 'L2564'],
#  ['L2565', 'L2566', 'L2567', 'L2568', 'L2569'],
#  ['L2570', 'L2571', 'L2572', 'L2573', 'L2574'],
#  ['L2577', 'L2578', 'L2579', 'L2580', 'L2581'],
#  ['L2908', 'L2909'],
#  ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915'],
#  ['L2557', 'L2558'],
#  ['L2559', 'L2560'],
#  ['L2561', 'L2562'],
#  ['L2635', 'L2636', 'L2637', 'L2638'],
#  ['L2639', 'L2640'],
#  ['L2666', 'L2667', 'L2668'],
#  ['L2670', 'L2671'],
#  ['L2778', 'L2779'],
#  ['L2780', 'L2781', 'L2782', 'L2783'],
#  ['L2789', 'L2790'],
#  ['L2842', 'L2843', 'L2844'],
#  ['L3083', 'L3084', 'L3085'],
#  ['L3087', 'L3088'],
#  ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188'],
#  ['L3189', 'L3190'],
#  ['L3191', 'L3192', 'L3193'],
#  ['L3246', 'L3247'],
#  ['L3250', 'L3251'],
#  ['L3356', 'L3357'],
#  ['L3359', 'L3360'],
#  ['L3361', 'L3362'],
#  ['L3363', 'L3364'],
#  ['L3365', 'L3366'],
#  ['L3368', 'L3369', 'L3370'],
#  ['L3372', 'L3373', 'L3374', 'L3375'],
#  ['L3376', 'L3377', 'L3378'],
#  ['L3547', 'L3548'],
#  ['L2672', 'L2673'],
#  ['L2674', 'L2675', 'L2676'],
#  ['L2678', 'L2679'],
#  ['L2680', 'L2681', 'L2682'],
#  ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692'],
#  ['L3271', 'L3272', 'L3273', 'L3274', 'L3275'],
#  ['L3352', 'L3353'],
#  ['L2608', 'L2609', 'L2610'],
#  ['L2614', 'L2615'],
#  ['L3409', 'L3410'],
#  ['L3411', 'L3412', 'L3413'],
#  ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269'],
#  ['L2575', 'L2576'],
#  ['L2582',
#   'L2583',
#   'L2584',
#   'L2585',
#   'L2586',
#   'L2587',
#   'L2588',
#   'L2589',
#   'L2590',
#   'L2591'],
#  ['L2732', 'L2733'],
#  ['L2740', 'L2741', 'L2742', 'L2743'],
#  ['L2744', 'L2745'],
#  ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403'],
#  ['L2698', 'L2699', 'L2700'],
#  ['L2701', 'L2702', 'L2703'],
#  ['L2706', 'L2707'],
#  ['L2771', 'L2772', 'L2773'],
#  ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813'],
#  ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721'],
#  ['L2724', 'L2725'],
#  ['L2735', 'L2736', 'L2737'],
#  ['L2738', 'L2739'],
#  ['L2754', 'L2755', 'L2756', 'L2757'],
#  ['L2767', 'L2768'],
#  ['L2793', 'L2794', 'L2795'],
#  ['L2863', 'L2864', 'L2865'],
#  ['L2870', 'L2871', 'L2872'],
#  ['L3024', 'L3025', 'L3026'],
#  ['L3287', 'L3288'],
#  ['L3342', 'L3343', 'L3344'],
#  ['L2928', 'L2929', 'L2930'],
#  ['L3422', 'L3423', 'L3424'],
#  ['L3425', 'L3426', 'L3427'],
#  ['L2828',
#   'L2829',
#   'L2830',
#   'L2831',
#   'L2832',
#   'L2833',
#   'L2834',
#   'L2835',
#   'L2836',
#   'L2837',
#   'L2838',
#   'L2839',
#   'L2840'],
#  ['L3712', 'L3713'],
#  ['L3720', 'L3721'],
#  ['L3728', 'L3729'],
#  ['L3749', 'L3750'],
#  ['L3756', 'L3757'],
#  ['L3770', 'L3771'],
#  ['L3777', 'L3778'],
#  ['L3942', 'L3943', 'L3944', 'L3945'],
#  ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969'],
#  ['L3972', 'L3973', 'L3974', 'L3975', 'L3976'],
#  ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984'],
#  ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992'],
#  ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001'],
#  ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017'],
#  ['L4159', 'L4160', 'L4161', 'L4162', 'L4163'],
#  ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193'],
#  ['L4196', 'L4197', 'L4198', 'L4199'],
#  ['L4208', 'L4209'],
#  ['L4282', 'L4283'],
#  ['L4296', 'L4297', 'L4298', 'L4299', 'L4300'],
#  ['L4006', 'L4007'],
#  ['L4068', 'L4069', 'L4070'],
#  ['L4079', 'L4080'],
#  ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224'],
#  ['L4227', 'L4228', 'L4229', 'L4230'],
#  ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271'],
#  ['L4333', 'L4334', 'L4335'],
#  ['L4346', 'L4347', 'L4348', 'L4349', 'L4350'],
#  ['L4353', 'L4354', 'L4355', 'L4356', 'L4357'],
#  ['L4360', 'L4361', 'L4362', 'L4363'],
#  ['L4366', 'L4367', 'L4368'],
#  ['L3970', 'L3971'],
#  ['L3977', 'L3978'],
#  ['L3993', 'L3994'],
#  ['L4002', 'L4003'],
#  ['L4009', 'L4010'],
#  ['L4018', 'L4019'],
#  ['L3668', 'L3669'],
#  ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677'],
#  ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685'],
#  ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693'],
#  ['L3797', 'L3798', 'L3799'],
#  ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810'],
#  ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735'],
#  ['L3758', 'L3759'],
#  ['L3774', 'L3775', 'L3776'],
#  ['L3779', 'L3780'],
#  ['L3622', 'L3623'],
#  ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631'],
#  ['L3651', 'L3652', 'L3653'],
#  ['L3724', 'L3725', 'L3726'],
#  ['L3738', 'L3739', 'L3740'],
#  ['L3745', 'L3746', 'L3747', 'L3748'],
#  ['L3751', 'L3752', 'L3753', 'L3754'],
#  ['L3760', 'L3761', 'L3762', 'L3763'],
#  ['L3766', 'L3767', 'L3768'],
#  ['L3772', 'L3773'],
#  ['L3868', 'L3869'],
#  ['L3889', 'L3890', 'L3891', 'L3892', 'L3893'],
#  ['L3896', 'L3897'],
#  ['L3904', 'L3905', 'L3906', 'L3907'],
#  ['L3817', 'L3818', 'L3819', 'L3820', 'L3821'],
#  ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829'],
#  ['L3832', 'L3833', 'L3834'],
#  ['L3837', 'L3838', 'L3839'],
#  ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025'],
#  ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033'],
#  ['L4096', 'L4097'],
#  ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113'],
#  ['L4118', 'L4119'],
#  ['L4169', 'L4170'],
#  ['L4174', 'L4175'],
#  ['L4181', 'L4182', 'L4183'],
#  ['L5039', 'L5040'],
#  ['L5041', 'L5042'],
#  ['L5043', 'L5044'],
#  ['L5045', 'L5046', 'L5047', 'L5048'],
#  ['L4897', 'L4898', 'L4899', 'L4900'],
#  ['L4903', 'L4904', 'L4905', 'L4906'],
#  ['L4922', 'L4923'],
#  ['L4924', 'L4925'],
#  ['L4453', 'L4454'],
#  ['L4501', 'L4502', 'L4503', 'L4504', 'L4505'],
#  ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511'],
#  ['L4562', 'L4563'],
#  ['L4567', 'L4568'],
#  ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180'],
#  ['L5181', 'L5182'],
#  ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188'],
#  ['L5193', 'L5194'],
#  ['L5215', 'L5216'],
#  ['L5366', 'L5367', 'L5368'],
#  ['L5370', 'L5371'],
#  ['L4944', 'L4945'],
#  ['L4959', 'L4960'],
#  ['L5316', 'L5317', 'L5318'],
#  ['L5321', 'L5322', 'L5323', 'L5324', 'L5325'],
#  ['L5328', 'L5329'],
#  ['L4628', 'L4629'],
#  ['L5338', 'L5339', 'L5340'],
#  ['L5346', 'L5347', 'L5348'],
#  ['L4727', 'L4728', 'L4729'],
#  ['L4731', 'L4732'],
#  ['L4739', 'L4740', 'L4741'],
#  ['L4743',
#   'L4744',
#   'L4745',
#   'L4746',
#   'L4747',
#   'L4748',
#   'L4749',
#   'L4750',
#   'L4751'],
#  ['L4763', 'L4764'],
#  ['L4765', 'L4766'],
#  ['L4769', 'L4770'],
#  ['L4771', 'L4772', 'L4773', 'L4774', 'L4775'],
#  ['L4778', 'L4779'],
#  ['L4780', 'L4781', 'L4782', 'L4783', 'L4784', 'L4785'],
#  ['L4786', 'L4787', 'L4788'],
#  ['L4789', 'L4790', 'L4791', 'L4792'],
#  ['L4800', 'L4801', 'L4802', 'L4803'],
#  ['L4814', 'L4815', 'L4816'],
#  ['L4825', 'L4826', 'L4827', 'L4828'],
#  ['L4848', 'L4849', 'L4850', 'L4851', 'L4852', 'L4853', 'L4854', 'L4855'],
#  ['L4857', 'L4858'],
#  ['L4860', 'L4861'],
#  ['L4863', 'L4864'],
#  ['L4866', 'L4867'],
#  ['L4868', 'L4869'],
#  ['L4870', 'L4871'],
#  ['L4873', 'L4874', 'L4875', 'L4876', 'L4877', 'L4878', 'L4879'],
#  ['L4880', 'L4881'],
#  ['L4882', 'L4883', 'L4884', 'L4885', 'L4886'],
#  ['L4887', 'L4888', 'L4889', 'L4890', 'L4891'],
#  ['L4893', 'L4894'],
#  ['L4895', 'L4896'],
#  ['L4911', 'L4912'],
#  ['L4929', 'L4930'],
#  ['L4937', 'L4938', 'L4939'],
#  ['L4964', 'L4965'],
#  ['L4969', 'L4970', 'L4971', 'L4972', 'L4973'],
#  ['L4974', 'L4975'],
#  ['L4994', 'L4995', 'L4996', 'L4997'],
#  ['L5002', 'L5003', 'L5004', 'L5005'],
#  ['L5007', 'L5008', 'L5009', 'L5010'],
#  ['L5011', 'L5012', 'L5013', 'L5014'],
#  ['L5016', 'L5017'],
#  ['L5018', 'L5019', 'L5020'],
#  ['L5021', 'L5022'],
#  ['L5023', 'L5024', 'L5025'],
#  ['L5028', 'L5029', 'L5030'],
#  ['L5033', 'L5034', 'L5035'],
#  ['L5036', 'L5037', 'L5038'],
#  ['L5049', 'L5050', 'L5051'],
#  ['L5052', 'L5053', 'L5054', 'L5055', 'L5056'],
#  ['L5057', 'L5058', 'L5059'],
#  ['L5060', 'L5061', 'L5062', 'L5063', 'L5064'],
#  ['L5065', 'L5066'],
#  ['L5067', 'L5068'],
#  ['L5069', 'L5070', 'L5071', 'L5072'],
#  ['L5073', 'L5074'],
#  ['L5076', 'L5077'],
#  ['L5083', 'L5084', 'L5085'],
#  ['L5171', 'L5172'],
#  ['L5190', 'L5191', 'L5192'],
#  ['L5195', 'L5196'],
#  ['L5197', 'L5198', 'L5199', 'L5200'],
#  ['L5201', 'L5202'],
#  ['L5204', 'L5205'],
#  ['L5206', 'L5207'],
#  ['L5208', 'L5209', 'L5210'],
#  ['L5212', 'L5213'],
#  ['L5224', 'L5225', 'L5226', 'L5227'],
#  ['L5236', 'L5237'],
#  ['L5249', 'L5250', 'L5251', 'L5252'],
#  ['L5253', 'L5254', 'L5255'],
#  ['L5256', 'L5257'],
#  ['L5290', 'L5291'],
#  ['L5304', 'L5305'],
#  ['L5306', 'L5307'],
#  ['L5308', 'L5309', 'L5310', 'L5311', 'L5312', 'L5313', 'L5314'],
#  ['L5351', 'L5352', 'L5353'],
#  ['L5372', 'L5373'],
#  ['L5375', 'L5376'],
#  ['L5377', 'L5378', 'L5379', 'L5380', 'L5381', 'L5382'],
#  ['L5383', 'L5384'],
#  ['L4689', 'L4690'],
#  ['L4691', 'L4692'],
#  ['L4693',
#   'L4694',
#   'L4695',
#   'L4696',
#   'L4697',
#   'L4698',
#   'L4699',
#   'L4700',
#   'L4701',
#   'L4702',
#   'L4703'],
#  ['L5093', 'L5094', 'L5095', 'L5096'],
#  ['L5097', 'L5098', 'L5099'],
#  ['L5100', 'L5101'],
#  ['L5102', 'L5103', 'L5104'],
#  ['L5242', 'L5243'],
#  ['L5244', 'L5245'],
#  ['L4636', 'L4637', 'L4638', 'L4639'],
#  ['L4642', 'L4643', 'L4644'],
#  ['L4669', 'L4670', 'L4671'],
#  ['L4672', 'L4673'],
#  ['L4675', 'L4676'],
#  ['L4677', 'L4678', 'L4679', 'L4680'],
#  ['L4681', 'L4682'],
#  ['L4685', 'L4686', 'L4687'],
#  ['L5132', 'L5133', 'L5134', 'L5135', 'L5136', 'L5137', 'L5138'],
#  ['L5142', 'L5143'],
#  ['L5144', 'L5145'],
#  ['L5158', 'L5159'],
#  ['L5162', 'L5163'],
#  ['L4809', 'L4810', 'L4811', 'L4812', 'L4813'],
#  ['L4817', 'L4818', 'L4819'],
#  ['L4821', 'L4822', 'L4823'],
#  ['L4467', 'L4468'],
#  ['L4469', 'L4470', 'L4471'],
#  ['L4472', 'L4473', 'L4474'],
#  ['L4475', 'L4476'],
#  ['L4477',
#   'L4478',
#   'L4479',
#   'L4480',
#   'L4481',
#   'L4482',
#   'L4483',
#   'L4484',
#   'L4485',
#   'L4486',
#   'L4487',
#   'L4488'],
#  ['L4513', 'L4514'],
#  ['L4516', 'L4517'],
#  ['L4519', 'L4520', 'L4521', 'L4522'],
#  ['L4523', 'L4524', 'L4525'],
#  ['L4528', 'L4529', 'L4530', 'L4531', 'L4532'],
#  ['L4533', 'L4534', 'L4535'],
#  ['L4704', 'L4705', 'L4706'],
#  ['L4707', 'L4708', 'L4709'],
#  ['L4712', 'L4713', 'L4714', 'L4715', 'L4716', 'L4717', 'L4718'],
#  ['L4836', 'L4837'],
#  ['L4839', 'L4840'],
#  ['L5149', 'L5150', 'L5151', 'L5152', 'L5153'],
#  ['L5164', 'L5165'],
#  ['L5167', 'L5168', 'L5169'],
#  ['L5219', 'L5220', 'L5221'],
#  ['L5258', 'L5259', 'L5260', 'L5261', 'L5262', 'L5263'],
#  ['L5275', 'L5276'],
#  ['L5284', 'L5285', 'L5286', 'L5287'],
#  ['L5292', 'L5293', 'L5294', 'L5295', 'L5296', 'L5297', 'L5298'],
#  ['L5301', 'L5302', 'L5303'],
#  ['L5355', 'L5356', 'L5357', 'L5358'],
#  ['L5359', 'L5360', 'L5361', 'L5362', 'L5363'],
#  ['L5364', 'L5365'],
#  ['L5264', 'L5265'],
#  ['L5266', 'L5267', 'L5268'],
#  ['L5279', 'L5280', 'L5281', 'L5282'],
#  ['L5288', 'L5289'],
#  ['L4600', 'L4601', 'L4602'],
#  ['L4603', 'L4604'],
#  ['L4609', 'L4610'],
#  ['L4612', 'L4613'],
#  ['L4493', 'L4494'],
#  ['L4495', 'L4496', 'L4497', 'L4498', 'L4499', 'L4500'],
#  ['L4543', 'L4544', 'L4545', 'L4546', 'L4547'],
#  ['L4548', 'L4549', 'L4550', 'L4551', 'L4552', 'L4553', 'L4554', 'L4555'],
#  ['L4558', 'L4559'],
#  ['L5230', 'L5231'],
#  ['L5233', 'L5234'],
#  ['L5105', 'L5106'],
#  ['L5107', 'L5108'],
#  ['L5109', 'L5110'],
#  ['L5113', 'L5114'],
#  ['L5115', 'L5116', 'L5117', 'L5118', 'L5119', 'L5120'],
#  ['L5121', 'L5122', 'L5123'],
#  ['L5124', 'L5125'],
#  ['L5643', 'L5644', 'L5645'],
#  ['L5673', 'L5674'],
#  ['L5678', 'L5679', 'L5680'],
#  ['L5692', 'L5693'],
#  ['L5875', 'L5876'],
#  ['L5889', 'L5890'],
#  ['L5710', 'L5711'],
#  ['L5737',
#   'L5738',
#   'L5739',
#   'L5740',
#   'L5741',
#   'L5742',
#   'L5743',
#   'L5744',
#   'L5745'],
#  ['L5746', 'L5747', 'L5748'],
#  ['L5751', 'L5752'],
#  ['L5754', 'L5755', 'L5756'],
#  ['L5760', 'L5761'],
#  ['L5613', 'L5614'],
#  ['L5615', 'L5616', 'L5617'],
#  ['L5620', 'L5621', 'L5622'],
#  ['L5624', 'L5625', 'L5626', 'L5627', 'L5628'],
#  ['L5648', 'L5649', 'L5650', 'L5651'],
#  ['L5652', 'L5653', 'L5654', 'L5655'],
#  ['L5656', 'L5657', 'L5658'],
#  ['L5826', 'L5827', 'L5828', 'L5829', 'L5830', 'L5831', 'L5832', 'L5833'],
#  ['L5839', 'L5840'],
#  ['L6168', 'L6169', 'L6170', 'L6171', 'L6172'],
#  ['L6258', 'L6259'],
#  ['L6263', 'L6264', 'L6265', 'L6266'],
#  ['L5463', 'L5464'],
#  ['L5468', 'L5469', 'L5470'],
#  ['L5508', 'L5509', 'L5510'],
#  ['L5511', 'L5512'],
#  ['L5515', 'L5516'],
#  ['L5521', 'L5522'],
#  ['L5556', 'L5557'],
#  ['L5630', 'L5631', 'L5632'],
#  ['L5636', 'L5637'],
#  ['L5646', 'L5647'],
#  ['L5671', 'L5672'],
#  ['L5675', 'L5676'],
#  ['L5686', 'L5687'],
#  ['L5688', 'L5689'],
#  ['L5730', 'L5731'],
#  ['L5911', 'L5912', 'L5913'],
#  ['L6251', 'L6252'],
#  ['L6105', 'L6106', 'L6107'],
#  ['L6108', 'L6109', 'L6110'],
#  ['L6114', 'L6115', 'L6116', 'L6117', 'L6118', 'L6119', 'L6120'],
#  ['L6123', 'L6124'],
#  ['L5488', 'L5489'],
#  ['L5490', 'L5491', 'L5492'],
#  ['L5493', 'L5494', 'L5495', 'L5496'],
#  ['L5497', 'L5498', 'L5499'],
#  ['L5501', 'L5502', 'L5503', 'L5504', 'L5505', 'L5506'],
#  ['L5664', 'L5665', 'L5666', 'L5667', 'L5668'],
#  ['L5669', 'L5670'],
#  ['L5596', 'L5597'],
#  ['L5605', 'L5606'],
#  ['L5609', 'L5610'],
#  ['L5611', 'L5612'],
#  ['L5633', 'L5634'],
#  ['L5638', 'L5639', 'L5640', 'L5641'],
#  ['L5420', 'L5421'],
#  ['L5422', 'L5423', 'L5424', 'L5425'],
#  ['L5426', 'L5427'],
#  ['L5777', 'L5778', 'L5779', 'L5780'],
#  ['L5782', 'L5783'],
#  ['L5785', 'L5786'],
#  ['L5787', 'L5788', 'L5789'],
#  ['L5790', 'L5791', 'L5792'],
#  ['L5880', 'L5881', 'L5882'],
#  ['L6029', 'L6030', 'L6031', 'L6032'],
#  ['L5543', 'L5544'],
#  ['L5545', 'L5546', 'L5547', 'L5548'],
#  ['L5834', 'L5835'],
#  ['L6208', 'L6209'],
#  ['L6211', 'L6212'],
#  ['L5922', 'L5923'],
#  ['L5924', 'L5925'],
#  ['L5933', 'L5934'],
#  ['L6020', 'L6021', 'L6022', 'L6023', 'L6024', 'L6025', 'L6026'],
#  ['L6132', 'L6133'],
#  ['L6156', 'L6157', 'L6158'],
#  ['L6183', 'L6184'],
#  ['L6190', 'L6191'],
#  ['L6206', 'L6207'],
#  ['L6213', 'L6214'],
#  ['L6215', 'L6216'],
#  ['L6278', 'L6279', 'L6280'],
#  ['L6282', 'L6283'],
#  ['L5794', 'L5795', 'L5796', 'L5797', 'L5798', 'L5799', 'L5800'],
#  ['L5801', 'L5802', 'L5803'],
#  ['L5804', 'L5805', 'L5806'],
#  ['L5809', 'L5810', 'L5811', 'L5812', 'L5813'],
#  ['L5815', 'L5816'],
#  ['L5817', 'L5818', 'L5819'],
#  ['L5820', 'L5821', 'L5822'],
#  ['L5824', 'L5825'],
#  ['L5858', 'L5859'],
#  ['L5869', 'L5870', 'L5871'],
#  ['L5900', 'L5901'],
#  ['L5943', 'L5944'],
#  ['L5946', 'L5947'],
#  ['L5949', 'L5950'],
#  ['L5954', 'L5955', 'L5956', 'L5957'],
#  ['L5958', 'L5959', 'L5960', 'L5961', 'L5962', 'L5963', 'L5964', 'L5965'],
#  ['L6051', 'L6052', 'L6053', 'L6054', 'L6055', 'L6056'],
#  ['L6057', 'L6058', 'L6059'],
#  ['L6062', 'L6063', 'L6064'],
#  ['L6066', 'L6067'],
#  ['L6237', 'L6238', 'L6239', 'L6240', 'L6241'],
#  ['L6267', 'L6268', 'L6269', 'L6270'],
#  ['L6289', 'L6290', 'L6291', 'L6292', 'L6293'],
#  ['L6297', 'L6298', 'L6299', 'L6300', 'L6301'],
#  ['L6302', 'L6303', 'L6304', 'L6305'],
#  ['L6308', 'L6309'],
#  ['L5722', 'L5723', 'L5724', 'L5725', 'L5726'],
#  ['L5728', 'L5729'],
#  ['L5531', 'L5532', 'L5533'],
#  ['L5534', 'L5535', 'L5536'],
#  ['L5537', 'L5538'],
#  ['L5539', 'L5540'],
#  ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567'],
#  ['L5568', 'L5569', 'L5570'],
#  ['L5573', 'L5574'],
#  ['L5585', 'L5586'],
#  ['L6313', 'L6314'],
#  ['L5767', 'L5768', 'L5769', 'L5770'],
#  ['L5773', 'L5774'],
#  ['L6254', 'L6255'],
#  ['L5441', 'L5442'],
#  ['L5443', 'L5444', 'L5445', 'L5446', 'L5447'],
#  ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453'],
#  ['L5479', 'L5480'],
#  ['L5396', 'L5397', 'L5398'],
#  ['L5399', 'L5400'],
#  ['L5404', 'L5405'],
#  ['L5406', 'L5407'],
#  ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225'],
#  ['L6002', 'L6003'],
#  ['L6004', 'L6005'],
#  ['L6006', 'L6007', 'L6008', 'L6009'],
#  ['L6011', 'L6012'],
#  ['L6335', 'L6336'],
#  ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344'],
#  ['L6347', 'L6348', 'L6349', 'L6350'],
#  ['L6351', 'L6352'],
#  ['L6361', 'L6362', 'L6363', 'L6364', 'L6365'],
#  ['L6429', 'L6430', 'L6431', 'L6432', 'L6433', 'L6434', 'L6435'],
#  ['L6957', 'L6958', 'L6959'],
#  ['L6960', 'L6961', 'L6962', 'L6963', 'L6964'],
#  ['L6971', 'L6972', 'L6973', 'L6974', 'L6975', 'L6976'],
#  ['L6977', 'L6978', 'L6979'],
#  ['L6980', 'L6981', 'L6982', 'L6983', 'L6984', 'L6985'],
#  ['L6986', 'L6987', 'L6988', 'L6989', 'L6990', 'L6991', 'L6992', 'L6993'],
#  ['L6996', 'L6997', 'L6998', 'L6999', 'L7000'],
#  ['L7001', 'L7002'],
#  ['L6605', 'L6606'],
#  ['L6607', 'L6608', 'L6609', 'L6610', 'L6611', 'L6612'],
#  ['L6707',
#   'L6708',
#   'L6709',
#   'L6710',
#   'L6711',
#   'L6712',
#   'L6713',
#   'L6714',
#   'L6715',
#   'L6716',
#   'L6717'],
#  ['L6909', 'L6910'],
#  ['L6779', 'L6780'],
#  ['L6781', 'L6782', 'L6783', 'L6784'],
#  ['L6789', 'L6790'],
#  ['L6791',
#   'L6792',
#   'L6793',
#   'L6794',
#   'L6795',
#   'L6796',
#   'L6797',
#   'L6798',
#   'L6799'],
#  ['L6800', 'L6801', 'L6802'],
#  ['L6803', 'L6804', 'L6805', 'L6806', 'L6807', 'L6808'],
#  ['L6810', 'L6811', 'L6812'],
#  ['L6814', 'L6815'],
#  ['L6828', 'L6829'],
#  ['L6830', 'L6831', 'L6832'],
#  ['L6833', 'L6834', 'L6835'],
#  ['L6840', 'L6841', 'L6842'],
#  ['L6844', 'L6845', 'L6846'],
#  ['L6852', 'L6853'],
#  ['L6858', 'L6859', 'L6860', 'L6861', 'L6862'],
#  ['L6863', 'L6864'],
#  ['L6847', 'L6848'],
#  ['L6865', 'L6866'],
#  ['L6906', 'L6907', 'L6908'],
#  ['L6911', 'L6912'],
#  ['L6935', 'L6936'],
#  ['L6437', 'L6438', 'L6439', 'L6440', 'L6441', 'L6442'],
#  ['L6443',
#   'L6444',
#   'L6445',
#   'L6446',
#   'L6447',
#   'L6448',
#   'L6449',
#   'L6450',
#   'L6451',
#   'L6452'],
#  ['L6453', 'L6454'],
#  ['L6460', 'L6461', 'L6462', 'L6463', 'L6464'],
#  ['L6693',
#   'L6694',
#   'L6695',
#   'L6696',
#   'L6697',
#   'L6698',
#   'L6699',
#   'L6700',
#   'L6701',
#   'L6702'],
#  ['L6919', 'L6920'],
#  ['L7013', 'L7014', 'L7015'],
#  ['L7016', 'L7017'],
#  ['L7018', 'L7019', 'L7020', 'L7021', 'L7022', 'L7023', 'L7024', 'L7025'],
#  ['L7026', 'L7027', 'L7028', 'L7029', 'L7030', 'L7031', 'L7032', 'L7033'],
#  ['L7034', 'L7035', 'L7036', 'L7037', 'L7038', 'L7039'],
#  ['L7043', 'L7044', 'L7045'],
#  ['L7048',
#   'L7049',
#   'L7050',
#   'L7051',
#   'L7052',
#   'L7053',
#   'L7054',
#   'L7055',
#   'L7056',
#   'L7057'],
#  ['L7059', 'L7060'],
#  ['L7061', 'L7062', 'L7063', 'L7064', 'L7065', 'L7066', 'L7067'],
#  ['L7070', 'L7071', 'L7072', 'L7073', 'L7074', 'L7075', 'L7076'],
#  ['L6686', 'L6687', 'L6688', 'L6689', 'L6690', 'L6691', 'L6692'],
#  ['L6374', 'L6375', 'L6376', 'L6377', 'L6378', 'L6379', 'L6380'],
#  ['L6868',
#   'L6869',
#   'L6870',
#   'L6871',
#   'L6872',
#   'L6873',
#   'L6874',
#   'L6875',
#   'L6876',
#   'L6877',
#   'L6878',
#   'L6879',
#   'L6880'],
#  ['L6881', 'L6882', 'L6883', 'L6884', 'L6885'],
#  ['L6886', 'L6887', 'L6888', 'L6889'],
#  ['L6890', 'L6891', 'L6892', 'L6893', 'L6894'],
#  ['L6898', 'L6899'],
#  ['L6900', 'L6901'],
#  ['L6902', 'L6903'],
#  ['L6921', 'L6922'],
#  ['L6546', 'L6547', 'L6548', 'L6549', 'L6550', 'L6551', 'L6552', 'L6553'],
#  ['L6556', 'L6557'],
#  ['L6558', 'L6559', 'L6560', 'L6561'],
#  ['L6568', 'L6569'],
#  ['L6570', 'L6571'],
#  ['L6574', 'L6575'],
#  ['L6576',
#   'L6577',
#   'L6578',
#   'L6579',
#   'L6580',
#   'L6581',
#   'L6582',
#   'L6583',
#   'L6584',
#   'L6585',
#   'L6586',
#   'L6587',
#   'L6588',
#   'L6589',
#   'L6590',
#   'L6591',
#   'L6592',
#   'L6593',
#   'L6594',
#   'L6595',
#   'L6596'],
#  ['L6597', 'L6598'],
#  ['L6614',
#   'L6615',
#   'L6616',
#   'L6617',
#   'L6618',
#   'L6619',
#   'L6620',
#   'L6621',
#   'L6622'],
#  ['L6623',
#   'L6624',
#   'L6625',
#   'L6626',
#   'L6627',
#   'L6628',
#   'L6629',
#   'L6630',
#   'L6631',
#   'L6632',
#   'L6633',
#   'L6634',
#   'L6635',
#   'L6636',
#   'L6637'],
#  ['L6722',
#   'L6723',
#   'L6724',
#   'L6725',
#   'L6726',
#   'L6727',
#   'L6728',
#   'L6729',
#   'L6730',
#   'L6731',
#   'L6732',
#   'L6733',
#   'L6734',
#   'L6735',
#   'L6736',
#   'L6737'],
#  ['L6750', 'L6751', 'L6752'],
#  ['L6753', 'L6754'],
#  ['L6757', 'L6758'],
#  ['L6762', 'L6763', 'L6764', 'L6765'],
#  ['L6768', 'L6769'],
#  ['L6787', 'L6788'],
#  ['L6816', 'L6817', 'L6818', 'L6819'],
#  ['L6821', 'L6822'],
#  ['L6823', 'L6824'],
#  ['L6368', 'L6369'],
#  ['L6372', 'L6373'],
#  ['L6382', 'L6383'],
#  ['L6384', 'L6385'],
#  ['L6386', 'L6387', 'L6388'],
#  ['L6389', 'L6390', 'L6391', 'L6392'],
#  ['L6395', 'L6396', 'L6397', 'L6398'],
#  ['L6399', 'L6400', 'L6401'],
#  ['L6402', 'L6403', 'L6404', 'L6405', 'L6406'],
#  ['L6407', 'L6408', 'L6409'],
#  ['L6410', 'L6411'],
#  ['L6412', 'L6413', 'L6414', 'L6415', 'L6416', 'L6417', 'L6418'],
#  ['L6419', 'L6420', 'L6421', 'L6422', 'L6423', 'L6424'],
#  ['L6425', 'L6426', 'L6427', 'L6428'],
#  ['L6639', 'L6640', 'L6641', 'L6642'],
#  ['L6643', 'L6644', 'L6645', 'L6646', 'L6647'],
#  ['L6648', 'L6649', 'L6650', 'L6651', 'L6652', 'L6653', 'L6654', 'L6655'],
#  ['L6738',
#   'L6739',
#   'L6740',
#   'L6741',
#   'L6742',
#   'L6743',
#   'L6744',
#   'L6745',
#   'L6746'],
#  ['L6747', 'L6748', 'L6749'],
#  ['L6466', 'L6467'],
#  ['L6468', 'L6469', 'L6470', 'L6471', 'L6472'],
#  ['L6473', 'L6474', 'L6475', 'L6476', 'L6477'],
#  ['L6479', 'L6480', 'L6481'],
#  ['L6482', 'L6483'],
#  ['L6485',
#   'L6486',
#   'L6487',
#   'L6488',
#   'L6489',
#   'L6490',
#   'L6491',
#   'L6492',
#   'L6493',
#   'L6494',
#   'L6495',
#   'L6496',
#   'L6497',
#   'L6498',
#   'L6499',
#   'L6500',
#   'L6501',
#   'L6502'],
#  ['L6503', 'L6504'],
#  ['L6507', 'L6508'],
#  ['L6511', 'L6512', 'L6513', 'L6514', 'L6515'],
#  ['L6516',
#   'L6517',
#   'L6518',
#   'L6519',
#   'L6520',
#   'L6521',
#   'L6522',
#   'L6523',
#   'L6524'],
#  ['L6525', 'L6526', 'L6527', 'L6528'],
#  ['L6531', 'L6532'],
#  ['L6534', 'L6535', 'L6536'],
#  ['L7081', 'L7082', 'L7083', 'L7084'],
#  ['L7085', 'L7086', 'L7087'],
#  ['L7088',
#   'L7089',
#   'L7090',
#   'L7091',
#   'L7092',
#   'L7093',
#   'L7094',
#   'L7095',
#   'L7096',
#   'L7097',
#   'L7098'],
#  ['L6657', 'L6658', 'L6659'],
#  ['L6661', 'L6662'],
#  ['L6665', 'L6666', 'L6667', 'L6668'],
#  ['L6669', 'L6670', 'L6671'],
#  ['L6354', 'L6355', 'L6356', 'L6357'],
#  ['L6358', 'L6359', 'L6360'],
#  ['L6676', 'L6677', 'L6678'],
#  ['L6679', 'L6680', 'L6681'],
#  ['L6682', 'L6683', 'L6684'],
#  ['L8029', 'L8030', 'L8031', 'L8032'],
#  ['L8033', 'L8034', 'L8035'],
#  ['L8036', 'L8037'],
#  ['L8094', 'L8095', 'L8096', 'L8097'],
#  ['L8155', 'L8156'],
#  ['L8196', 'L8197', 'L8198', 'L8199'],
#  ...]

# %%
# Getting separately the questions and the answers
questions = []
answers = []
for conversation in conversations_ids:
    for i in range(len(conversation) - 1):
        questions.append(id2line[conversation[i]])
        answers.append(id2line[conversation[i+1]])

# %%
# Doing a first cleaning of the texts
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-()\"#/@;:<>{}+=~|.?,]", "", text)
    return text

# %%
# Cleaning the questions
clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))
 
# Cleaning the answers
clean_answers = []
for answer in answers:
    clean_answers.append(clean_text(answer))

# %%
# Creating a dictionary that maps each word to its number of occurrences
word2count = {}
for question in clean_questions:
    for word in question.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1
for answer in clean_answers:
    for word in answer.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
# Creating two dictionaries that map the questions words and the answers words to a unique integer
threshold_questions = 20
questionswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_questions:
        questionswords2int[word] = word_number
        word_number += 1
threshold_answers = 20
answerswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_answers:
        answerswords2int[word] = word_number
        word_number += 1

# %%
# Adding the last tokens to these two dictionaries
tokens = ['<PAD>', '<EOS>', '<OUT>', '<SOS>']
for token in tokens:
    questionswords2int[token] = len(questionswords2int) + 1
for token in tokens:
    answerswords2int[token] = len(answerswords2int) + 1

# %%
# Creating the inverse dictionary of the answerswords2int dictionary
answersints2word = {w_i: w for w, w_i in answerswords2int.items()}
 
# Adding the End Of String token to the end of every answer
for i in range(len(clean_answers)):
    clean_answers[i] += ' <EOS>'

# %%
# Translating all the questions and the answers into integers
# and Replacing all the words that were filtered out by <OUT> 
questions_into_int = []
for question in clean_questions:
    ints = []
    for word in question.split():
        if word not in questionswords2int:
            ints.append(questionswords2int['<OUT>'])
        else:
            ints.append(questionswords2int[word])
    questions_into_int.append(ints)
answers_into_int = []
for answer in clean_answers:
    ints = []
    for word in answer.split():
        if word not in answerswords2int:
            ints.append(answerswords2int['<OUT>'])
        else:
            ints.append(answerswords2int[word])
    answers_into_int.append(ints)

# %%
# Sorting questions and answers by the length of questions
sorted_clean_questions = []
sorted_clean_answers = []
for length in range(1, 25 + 1):
    for i in enumerate(questions_into_int):
        if len(i[1]) == length:
            sorted_clean_questions.append(questions_into_int[i[0]])
            sorted_clean_answers.append(answers_into_int[i[0]])

# %%
########## PART 2 - BUILDING THE SEQ2SEQ MODEL ##########
 
 
 
# Creating placeholders for the inputs and the targets
def model_inputs():
    inputs = tf.placeholder(tf.int32, [None, None], name = 'input')
    targets = tf.placeholder(tf.int32, [None, None], name = 'target')
    lr = tf.placeholder(tf.float32, name = 'learning_rate')
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    return inputs, targets, lr, keep_prob
 
# Preprocessing the targets
def preprocess_targets(targets, word2int, batch_size):
    left_side = tf.fill([batch_size, 1], word2int['<SOS>'])
    right_side = tf.strided_slice(targets, [0,0], [batch_size, -1], [1,1])
    preprocessed_targets = tf.concat([left_side, right_side], 1)
    return preprocessed_targets
 
# Creating the Encoder RNN
def encoder_rnn(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length):
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
    encoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
    encoder_output, encoder_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = encoder_cell,
                                                                    cell_bw = encoder_cell,
                                                                    sequence_length = sequence_length,
                                                                    inputs = rnn_inputs,
                                                                    dtype = tf.float32)
    return encoder_state

# %%
def decode_training_set(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob, batch_size): 
    '''Decode the training data'''

    attention_states = tf.zeros([batch_size, 1, dec_cell.output_size])

    att_keys, att_vals, att_score_fn, att_construct_fn = tf.contrib.seq2seq.prepare_attention(attention_states,
                                                 attention_option="bahdanau",
                                                 num_units=dec_cell.output_size)

    train_decoder_fn = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                     att_keys,
                                                                     att_vals,
                                                                     att_score_fn,
                                                                     att_construct_fn,
                                                                     name = "attn_dec_train")
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell,
                                                              train_decoder_fn,
                                                              dec_embed_input,
                                                              sequence_length,
                                                              scope=decoding_scope)
    train_pred_drop = tf.nn.dropout(train_pred, keep_prob)
    return output_fn(train_pred_drop)

# %%
 
# Decoding the training set
def decode_training_set(encoder_state, decoder_cell, decoder_embedded_input, sequence_length, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    training_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              name = "attn_dec_train")
    decoder_output, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                              training_decoder_function,
                                                                                                              decoder_embedded_input,
                                                                                                              sequence_length,
                                                                                                              scope = decoding_scope)
    decoder_output_dropout = tf.nn.dropout(decoder_output, keep_prob)
    return output_function(decoder_output_dropout)

# %%
# Decoding the test/validation set
def decode_test_set(encoder_state, decoder_cell, decoder_embeddings_matrix, sos_id, eos_id, maximum_length, num_words, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    test_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_inference(output_function,
                                                                              encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              decoder_embeddings_matrix,
                                                                              sos_id,
                                                                              eos_id,
                                                                              maximum_length,
                                                                              num_words,
                                                                              name = "attn_dec_inf")
    test_predictions, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                                test_decoder_function,
                                                                                                                scope = decoding_scope)
    return test_predictions

# %%
 
# Creating the Decoder RNN
def decoder_rnn(decoder_embedded_input, decoder_embeddings_matrix, encoder_state, num_words, sequence_length, rnn_size, num_layers, word2int, keep_prob, batch_size):
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        decoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        biases = tf.zeros_initializer()
        output_function = lambda x: tf.contrib.layers.fully_connected(x,
                                                                      num_words,
                                                                      None,
                                                                      scope = decoding_scope,
                                                                      weights_initializer = weights,
                                                                      biases_initializer = biases)
        training_predictions = decode_training_set(encoder_state,
                                                   decoder_cell,
                                                   decoder_embedded_input,
                                                   sequence_length,
                                                   decoding_scope,
                                                   output_function,
                                                   keep_prob,
                                                   batch_size)
        decoding_scope.reuse_variables()
        test_predictions = decode_test_set(encoder_state,
                                           decoder_cell,
                                           decoder_embeddings_matrix,
                                           word2int['<SOS>'],
                                           word2int['<EOS>'],
                                           sequence_length - 1,
                                           num_words,
                                           decoding_scope,
                                           output_function,
                                           keep_prob,
                                           batch_size)
    return training_predictions, test_predictions
 
# Building the seq2seq model
def seq2seq_model(inputs, targets, keep_prob, batch_size, sequence_length, answers_num_words, questions_num_words, encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers, questionswords2int):
    encoder_embedded_input = tf.contrib.layers.embed_sequence(inputs,
                                                              answers_num_words + 1,
                                                              encoder_embedding_size,
                                                              initializer = tf.random_uniform_initializer(0, 1))
    encoder_state = encoder_rnn(encoder_embedded_input, rnn_size, num_layers, keep_prob, sequence_length)
    preprocessed_targets = preprocess_targets(targets, questionswords2int, batch_size)
    decoder_embeddings_matrix = tf.Variable(tf.random_uniform([questions_num_words + 1, decoder_embedding_size], 0, 1))
    decoder_embedded_input = tf.nn.embedding_lookup(decoder_embeddings_matrix, preprocessed_targets)
    training_predictions, test_predictions = decoder_rnn(decoder_embedded_input,
                                                         decoder_embeddings_matrix,
                                                         encoder_state,
                                                         questions_num_words,
                                                         sequence_length,
                                                         rnn_size,
                                                         num_layers,
                                                         questionswords2int,
                                                         keep_prob,
                                                         batch_size)
    return training_predictions, test_predictions

# %%
########## PART 3 - TRAINING THE SEQ2SEQ MODEL ##########
 
 
 
# Setting the Hyperparameters
epochs = 100
batch_size = 64
rnn_size = 512
num_layers = 3
encoding_embedding_size = 512
decoding_embedding_size = 512
learning_rate = 0.01
learning_rate_decay = 0.9
min_learning_rate = 0.0001
keep_probability = 0.5
 
# Defining a session
tf.reset_default_graph()
session = tf.InteractiveSession()
 
# Loading the model inputs
inputs, targets, lr, keep_prob = model_inputs()
 
# Setting the sequence length
sequence_length = tf.placeholder_with_default(25, None, name = 'sequence_length')
 
# Getting the shape of the inputs tensor
input_shape = tf.shape(inputs)

# %%
# Getting the training and test predictions
training_predictions, test_predictions = seq2seq_model(tf.reverse(inputs, [-1]),
                                                       targets,
                                                       keep_prob,
                                                       batch_size,
                                                       sequence_length,
                                                       len(answerswords2int),
                                                       len(questionswords2int),
                                                       encoding_embedding_size,
                                                       decoding_embedding_size,
                                                       rnn_size,
                                                       num_layers,
                                                       questionswords2int)
 
# Setting up the Loss Error, the Optimizer and Gradient Clipping
with tf.name_scope("optimization"):
    loss_error = tf.contrib.seq2seq.sequence_loss(training_predictions,
                                                  targets,
                                                  tf.ones([input_shape[0], sequence_length]))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss_error)
    clipped_gradients = [(tf.clip_by_value(grad_tensor, -5., 5.), grad_variable) for grad_tensor, grad_variable in gradients if grad_tensor is not None]
    optimizer_gradient_clipping = optimizer.apply_gradients(clipped_gradients)
 
# Padding the sequences with the <PAD> token
def apply_padding(batch_of_sequences, word2int):
    max_sequence_length = max([len(sequence) for sequence in batch_of_sequences])
    return [sequence + [word2int['<PAD>']] * (max_sequence_length - len(sequence)) for sequence in batch_of_sequences]

# %%
# Splitting the data into batches of questions and answers
def split_into_batches(questions, answers, batch_size):
    for batch_index in range(0, len(questions) // batch_size):
        start_index = batch_index * batch_size
        questions_in_batch = questions[start_index : start_index + batch_size]
        answers_in_batch = answers[start_index : start_index + batch_size]
        padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionswords2int))
        padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerswords2int))
        yield padded_questions_in_batch, padded_answers_in_batch

# %%
# Splitting the questions and answers into training and validation sets
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]
 
# Training
batch_index_check_training_loss = 100
batch_index_check_validation_loss = ((len(training_questions)) // batch_size // 2) - 1
total_training_loss_error = 0
list_validation_loss_error = []
early_stopping_check = 0
early_stopping_stop = 1000
checkpoint = "chatbot_weights.ckpt" # For Windows users, replace this line of code by: checkpoint = "./chatbot_weights.ckpt"
session.run(tf.global_variables_initializer())
for epoch in range(1, epochs + 1):
    for batch_index, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(training_questions, training_answers, batch_size)):
        starting_time = time.time()
        _, batch_training_loss_error = session.run([optimizer_gradient_clipping, loss_error], {inputs: padded_questions_in_batch,
                                                                                               targets: padded_answers_in_batch,
                                                                                               lr: learning_rate,
                                                                                               sequence_length: padded_answers_in_batch.shape[1],
                                                                                               keep_prob: keep_probability})
        total_training_loss_error += batch_training_loss_error
        ending_time = time.time()
        batch_time = ending_time - starting_time
        if batch_index % batch_index_check_training_loss == 0:
            print('Epoch: {:>3}/{}, Batch: {:>4}/{}, Training Loss Error: {:>6.3f}, Training Time on 100 Batches: {:d} seconds'.format(epoch,
                                                                                                                                       epochs,
                                                                                                                                       batch_index,
                                                                                                                                       len(training_questions) // batch_size,
                                                                                                                                       total_training_loss_error / batch_index_check_training_loss,
                                                                                                                                       int(batch_time * batch_index_check_training_loss)))
            total_training_loss_error = 0
        if batch_index % batch_index_check_validation_loss == 0 and batch_index > 0:
            total_validation_loss_error = 0
            starting_time = time.time()
            for batch_index_validation, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(validation_questions, validation_answers, batch_size)):
                batch_validation_loss_error = session.run(loss_error, {inputs: padded_questions_in_batch,
                                                                       targets: padded_answers_in_batch,
                                                                       lr: learning_rate,
                                                                       sequence_length: padded_answers_in_batch.shape[1],
                                                                       keep_prob: 1})
                total_validation_loss_error += batch_validation_loss_error
            ending_time = time.time()
            batch_time = ending_time - starting_time
            average_validation_loss_error = total_validation_loss_error / (len(validation_questions) / batch_size)
            print('Validation Loss Error: {:>6.3f}, Batch Validation Time: {:d} seconds'.format(average_validation_loss_error, int(batch_time)))
            learning_rate *= learning_rate_decay
            if learning_rate < min_learning_rate:
                learning_rate = min_learning_rate
            list_validation_loss_error.append(average_validation_loss_error)
            if average_validation_loss_error <= min(list_validation_loss_error):
                print('I speak better now!!')
                early_stopping_check = 0
                saver = tf.train.Saver()
                saver.save(session, checkpoint)
            else:
                print("Sorry I do not speak better, I need to practice more.")
                early_stopping_check += 1
                if early_stopping_check == early_stopping_stop:
                    break
    if early_stopping_check == early_stopping_stop:
        print("My apologies, I cannot speak better anymore. This is the best I can do.")
        break
print("Game Over")
# Out:
# Epoch:   1/100, Batch:    0/2708, Training Loss Error:  0.091, Training Time on 100 Batches: 905 seconds
